# %% [markdown]
# ## Blackjack Game by Leonardo

# %%
from art import tprint
import random
import ipyplot
import cv2
import glob
import numpy as np
import time

# %% [markdown]
# ## Global variable declarations:

# %%
game_break = False
round_number = 1

player_wins = 0
cpu_wins = 0
ties = 0

round_break = False
turn_number = 1
draw_or_stop = "DRAW"

cards = []
player_cards = []
cpu_cards = []

player_scores = []
cpu_scores = []

player_total_score = 0
cpu_total_score = 0

player_money = 0
cpu_money = 0
bet = 0

# %% [markdown]
# Deck will be defined here as a single deck of cards and related to their face value in BlackJack. For that matter, it's datatype will be a dictionary in Python.
# Cards will be defined per consequence as the mix of cards played in the game. Therefore, it could be composed on between 1 to 8 decks. A list datatype suffises for my intentions with the game.

# %%
deck = {}
# The deck will be composed by a dictionary, with keys defined as the card name and the values defining
# the points/score for each card

for i in ["♠", "♥", "♦", "♣"]:
    for j in range(2,11):
        deck[str(j)+i] = j

    for k in ["J", "Q", "K"]:
        deck[str(k)+i] = 10

    deck["A"+i] = "choose"

cards = list(deck.keys())

# %% [markdown]
# ## Functions declarations

# %%
def welcome_screen():
    """
    Function with the purpose of greeting the player and inviting him to play
    
    Output: a graphic visual with the game's name
    """
    
    tprint("BLACK",font="block")
    tprint("JACK",font="block")
    
    print()
    print('{:^110}'.format('ARE YOU READY FOR A CHICKEN DINNER ?'))
    print()
    print("-"*110)
    print("-"*110)
    print("-"*110)
    print()
    
    return None

# %% [raw]
# from matplotlib import image
# from matplotlib import pyplot
#
# def show_deck():
#
#     deck_image = image.imread('deck.png', width=1000)
#     pyplot.imshow(deck_image)
#     pyplot.show()
#
#     return None

# %%
def show_deck(number_of_decks_used):

    deck_image = []
    files = glob.glob("/Users/oleoaraujo/Documents/Github/data-ft-par-labs/Projects/Week-1/your-project/*.png")
    
    for i in range(number_of_decks_used):
        for myFile in files:
            image = cv2.imread(myFile)
            deck_image.append(image)
    
    if number_of_decks_used == 1:
        ipyplot.plot_images(deck_image, max_images=8, img_width=900)
    if number_of_decks_used > 1:
        ipyplot.plot_images(deck_image, max_images=8, img_width=450)
    
    return None

# %%
def number_of_decks():
    
    global number_of_decks_used, cards
    
    number_of_decks_used = input("Choose the number of decks you would like to play with (from 1 to 8): \n")
    
    while number_of_decks_used not in range(1,9):
        try:
            number_of_decks_used = int(number_of_decks_used)
        except:
            number_of_decks_used = input("Please, try again. You need to choose an integer between 1 and 8 for the number of decks:\n")
        else:
            number_of_decks_used = int(number_of_decks_used)
    
    cards = []
    for i in range(number_of_decks_used):
        cards += list(deck.keys())
    
    print(f"\nNice choice! Your deck has then {len(cards)} CARDS and here are the cards in your full deck:")
    show_deck(number_of_decks_used)
    
    option_quit_game()
    
    return None

# %%
def reset_all(deck=deck):
    """
    This function has the objective of reseting:
    1. the deck of cards after every round, since the deck is used with no replacement of cards during each turn of play
    2. all the other variables related to the player and the CPU
    
    Input: deck (as a dictionary)
    Output: cards = multiple times the deck (as a list)"""
    
    global turn_number, round_break, game_break, draw_or_stop, cards, player_cards, player_scores, player_total_score, cpu_cards, cpu_scores, cpu_total_score, number_of_decks_used, bet
    
    turn_number = 1
    round_break = False
    draw_or_stop = "DRAW"
    
    cards = []
    for i in range(number_of_decks_used):
        cards += list(deck.keys())
    
    player_cards = []
    player_scores = []
    player_total_score = 0
    player_money = 0
    
    cpu_cards = []
    cpu_scores = []
    cpu_total_score = 0
    
    bet = 0
    
    return None

# %%
def bets():
    """This function has the objective of keeping track of the bets made by the player.
    By default, the CPU will always accept the bet of the player and go agains him.
    It also updates the amount of money in the account of the PLAYER and CPU."""
    
    global player_money, cpu_money, turn_break, round_break, game_break, bet
    
    while player_money == 0 and cpu_money == 0:
        
        cpu_money = player_money = input("How many $ you want to place to your pot ? \n ")
        
        try:
            player_money = int(player_money)
        except:
            print("You should input A NUMBER for the bet. Please, try again.")
            player_money = 0
            cpu_money = 0
        else:
            if int(player_money) != player_money:
                print("You should input an INTEGER number for the bet. Please, try again.")
                player_money = 0
                cpu_money = 0
            else:
                player_money = int(player_money)
                cpu_money = int(player_money)
    
    print(f"\n\nYou have {player_money}$ available for betting.")
    print(f"The CPU has {cpu_money}$ available for betting.\n\n")
    
    if (player_money>0 and cpu_money==0) or (player_money==0 and cpu_money>0):
        turn_break = True
        round_break = True
        game_break = True
        return None
    
    bet = 0
    
    while bet == 0 and player_money>=0 and cpu_money>=0:
        
        bet = input(f"Place your bet for the round {round_number} : \n")
        
        try:
            bet = int(bet)
        except:
            print("You should input A NUMBER for the bet. Please, try again.")
        else:
            if int(bet) != bet:
                print("You should input an INTEGER number for the bet. Please, try again.")
                player_bet = 0
            elif int(bet)> player_money or int(bet)> cpu_money:
                max_bet = min(cpu_money, player_money)
                print(f"You should input a number equal of inferior to {max_bet}. Please, try again.")
                bet = 0
            else:
                bet = int(bet)
        
        print()
        print()
        
    return None

# %%
def choice_of_cards(cards=cards):
    """
    Function randomly choosing a card for the PLAYER or the CPU.
    """
    chosen_card = random.choices(cards)
    return chosen_card[0]

# %%
def option_quit_game():
    """
    Function to give the player the option to continue the game or to quit it between every new card been handled.
    """
    
    global round_break, game_break
    
    check = input("\nPress Enter to continue... Or Q to quit. ")
    if check.lower() == 'q':
        round_break = True
        game_break = True
    print()
    return None

# %%
def card_points(card_chosen, deck=deck):
    """This function determines the punctuation of each card (either draw by the player or the cpu)
    
    Input: card to be evaluated and the deck dictionary
    Output: punctuation of the card
    """
    
    #print(deck[card_chosen])
    
    if deck[card_chosen] in range (0,11):
        return deck[card_chosen]
    
    elif deck[card_chosen] == "choose":
        flag = True
        points = input("Nice ! You got an Ace ! Choose if you want to attribute 1 or 11 points to this card :\n")
        print()
        
        while flag:
            try:
                points = int(points)
            except:
                points=input("Please, try again. You need to choose 1 or 11 points to this card :\n")
            else:
                if int(points) == 1 or int(points) == 11:
                    flag = False
                    break
                else:
                    points=input("Please, try again. You need to choose 1 or 11 points to this card :\n")
        return int(points)
    
    else:
        print("There's a problem with the ponctuation of cards.\n")
        return 0

# %%
def player_choice():
    """This function requires a decision-making from the player: if he wants to keep drawing cards or if he wants to stop
    drawing cards."""
    
    global draw_or_stop
    
    if draw_or_stop.lower() in ["s", "stop"]:
        return "s"
    else:
        draw_or_stop = input("Press 'S' to STOP drawing cards. Any other key to continue drawing cards: ")
        
        draw_or_stop = draw_or_stop.lower()
        
        return draw_or_stop

# %%
#from IPython.display import Image
#Image(filename='9♥.jpg', width = 100)

def show_cards(cards):
    
    cards_images = []
    files = glob.glob("/Users/oleoaraujo/Documents/Github/data-ft-par-labs/Projects/Week-1/your-project/*.jpg")

    for card in cards:
        for myFile in files:
            if myFile == "/Users/oleoaraujo/Documents/Github/data-ft-par-labs/Projects/Week-1/your-project/"+card+".jpg":
                image = cv2.imread(myFile)
                cards_images.append(image)
    
    ipyplot.plot_images(cards_images, max_images=20, img_width=100)
    
    return None

# %%
def player_turn(turn_number=turn_number, cards=cards, deck=deck):
    """
    This function defines all the tasks that are executed when a card is to be drawn by the player,
    updating the necessary variables : from player_card, to the new cards (deck) and the player_score.
    """
    
    global player_total_score, player_scores, player_cards, draw_or_stop
    
    print(f"------------------------------------ TURN {turn_number} ------------------------------------")
    
    print("\n**PLAYER TURN:**")
    player_card = None
    
    if turn_number <= 2:
        print(f"For this turn (number {turn_number}) a new card has automatically been drawn to the player by the dealer (CPU).")
        draw_or_stop = "DRAW"
    
    elif turn_number >2:
        draw_or_stop = player_choice()
        
    if draw_or_stop.lower() not in ["s", "stop"]:
        player_card = choice_of_cards(cards)
        print(f"Here's the card : {player_card}.\n")
        
        # Drawing a card from the deck: removing it from the deck and allocating it to the player
        cards = cards.remove(player_card)
        player_cards.append(player_card)
        
        # Showing all the cards that have been drawn up to the PLAYER up until now
        show_cards(player_cards)
        
        # Score updates
        player_scores.append(card_points(player_card))
        player_total_score = sum(score for score in player_scores)
        
        #Image(filename=player_card+'.jpg', width=100)
    
    return None

# %%
def cpu_turn(turn_number=turn_number, cards=cards, deck=deck):
    
    global cpu_total_score, cpu_cards, round_break, game_break, draw_or_stop
    
    # Drawing a card from the deck: removing it from the deck and allocating it to the cpu:
    
    if turn_number==1 or draw_or_stop.lower() in ["stop", "s"]:
        cpu_card = choice_of_cards(cards)

        print("\n**CPU TURN:**")
        print("A new card has been drawn to the CPU.")
        print(f"Here's the card : {cpu_card}\n")

        cards = cards.remove(cpu_card)
        cpu_cards.append(cpu_card)

        # Showing all the cards that have been drawn up to the CPU up until now
        show_cards(cpu_cards)

        # Score updates
        cpu_scores.append(card_points(cpu_card))
        cpu_total_score = sum(score for score in cpu_scores)
        
        time.sleep(3)
    
    return None

# %%
def print_turn():
    
    if game_break == True:
        return None
    
    print(f"\n----------------------------------------------")
    print(f"-------------- TURN {turn_number} - RESULTS --------------")
    print(f"----------------------------------------------")
    print("")
    print("The PLAYER cards are:", player_cards)
    print("The PLAYER scores are:", player_scores)
    print("The PLAYER total score is:", player_total_score)
    print("")
    print("The CPU cards are:", cpu_cards)
    print("The CPU scores are:", cpu_scores)
    print("The CPU total score is:", cpu_total_score)
    print("")
    print(f"----------------------------------------------")
    print(f"----------------------------------------------")
    print(f"----------------------------------------------")
    
    return None

# %%
def print_round_winner():
    
    global player_wins, cpu_wins, ties, player_money, cpu_money, bet
    
    print("-"*110)
    print("-"*110)
    print("-"*110)
    print()
    
    if player_total_score > cpu_total_score and player_total_score <= 21:
        player_wins += 1
        player_money += bet
        cpu_money -= bet
        print("PLAYER IS THE WINNER OF THIS ROUND!")
        print(f"YOU WON {bet}$")
    
    elif cpu_total_score > 21 and player_total_score <= 21:
        player_wins += 1
        player_money += bet
        cpu_money -= bet
        print("PLAYER IS THE WINNER OF THIS ROUND!")
        print(f"YOU WON {bet}$")
    
    elif cpu_total_score > player_total_score and cpu_total_score <= 21:
        cpu_wins += 1
        cpu_money += bet
        player_money -= bet
        print("CPU IS THE WINNER OF THIS ROUND!")
        print(f"YOU LOST {bet}$")
        
    elif player_total_score > 21 and cpu_total_score <= 21:
        cpu_wins += 1
        cpu_money += bet
        player_money -= bet
        print("CPU IS THE WINNER OF THIS ROUND!")
        print(f"YOU LOST {bet}$")
    
    else:
        ties += 1
        print("IT'S A TIE!")
    
    print()
    print(f"The score of the game after round {round_number} is:\n")
    print(f"PLAYER WINS : {player_wins}       PLAYER POT: {player_money}")
    print(f"CPU WINS: {cpu_wins}              CPU POT: {cpu_money}")
    print(f"TIES : {ties}")
    print()
    
    print("-"*110)
    print("-"*110)
    print("-"*110)
    
    print("\n\n\n BRACE YOURSELF FOR ANOTHER ROUND\n\n\n")
    
    option_quit_game()
    
    return None

# %%
def print_final_result():
    
    print("\n#", "-"*108, "#", sep="")
    print("#", "-"*108, "#", sep="")
    print("#", "-"*108, "#", sep="")
    print("#", "-"*108, "#\n", sep="")
    
    if player_wins > cpu_wins:
        print('{:^110s}'.format("PLAYER is the absolute winner!\n"))
    elif cpu_wins > player_wins:
        print('{:^110s}'.format("CPU is the absolute winner!\n"))
    else:
        print('{:^110s}'.format("There's no winner for this game!\n"))
    
    print("#", "-"*108, "#", sep="")
    print("#", "-"*108, "#", sep="")
    print("#", "-"*108, "#", sep="")
    print("#", "-"*108, "#\n\n", sep="")
    
    return None

# %%
def goodbye_window():
    """
    Farewell to the player after he entered "Q" to quit the game.
    
    Output: a graphic visual with a goodbye message
    """
    
    tprint("GOODBYE","rnd-xlarge")
    #tprint("BYE",font="block")
    
    print()
    print('{:^110}'.format('SEE YOU SOON'))
    print()
    print()
    return None

# %% [raw]
# def check_winner(turn_number=turn_number, cpu_total_score=cpu_total_score, draw_or_stop=draw_or_stop):
#
#     global round_break
#
#     if turn_number>2 and cpu_total_score >=17 and draw_or_stop.lower() == "stop":
#         round_break = True
#
#     elif cpu_total_score>21 or player_total_score>21:
#         round_break = True
#
#     return round_break

# %% [markdown]
# ## Main Code Execution

# %%
welcome_screen()
number_of_decks()

# Looping each ROUND of play
while game_break == False:
    
    # Reseting the main variables
    reset_all()
    
    bets()
    
    # Looping each TURN of play
    while round_break == False:
        
        player_turn(turn_number)
        time.sleep(3)
        cpu_turn(turn_number)
        
        if player_total_score>21:
            round_break = True
        elif cpu_total_score >16:
            round_break = True
        
        if len(cards) > 0 and game_break == False:
            print_turn()
        
        option_quit_game()
        
        turn_number += 1
    
    if len(cards) >0 and game_break == False:
        print_round_winner()
    
    round_number += 1
    
print_final_result()

goodbye_window()
# Out:
#  .----------------.  .----------------.  .----------------.  .----------------.  .----------------.
# | .--------------. || .--------------. || .--------------. || .--------------. || .--------------. |
# | |   ______     | || |   _____      | || |      __      | || |     ______   | || |  ___  ____   | |
# | |  |_   _ \    | || |  |_   _|     | || |     /  \     | || |   .' ___  |  | || | |_  ||_  _|  | |
# | |    | |_) |   | || |    | |       | || |    / /\ \    | || |  / .'   \_|  | || |   | |_/ /    | |
# | |    |  __'.   | || |    | |   _   | || |   / ____ \   | || |  | |         | || |   |  __'.    | |
# | |   _| |__) |  | || |   _| |__/ |  | || | _/ /    \ \_ | || |  \ `.___.'\  | || |  _| |  \ \_  | |
# | |  |_______/   | || |  |________|  | || ||____|  |____|| || |   `._____.'  | || | |____||____| | |
# | |              | || |              | || |              | || |              | || |              | |
# | '--------------' || '--------------' || '--------------' || '--------------' || '--------------' |
#  '----------------'  '----------------'  '----------------'  '----------------'  '----------------'
#
#
#  .----------------.  .----------------.  .----------------.  .----------------.
# | .--------------. || .--------------. || .--------------. || .--------------. |
# | |     _____    | || |      __      | || |     ______   | || |  ___  ____   | |
# | |    |_   _|   | || |     /  \     | || |   .' ___  |  | || | |_  ||_  _|  | |
# | |      | |     | || |    / /\ \    | || |  / .'   \_|  | || |   | |_/ /    | |
# | |   _  | |     | || |   / ____ \   | || |  | |         | || |   |  __'.    | |
# | |  | |_' |     | || | _/ /    \ \_ | || |  \ `.___.'\  | || |  _| |  \ \_  | |
# | |  `.___.'     | || ||____|  |____|| || |   `._____.'  | || | |____||____| | |
# | |              | || |              | || |              | || |              | |
# | '--------------' || '--------------' || '--------------' || '--------------' |
#  '----------------'  '----------------'  '----------------'  '----------------'
#
#
#                                      ARE YOU READY FOR A CHICKEN DINNER ?
#
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
#
# Choose the number of decks you would like to play with (from 1 to 8):
# 1
#
# Nice choice! Your deck has then 52 CARDS and here are the cards in your full deck:
#     <style>
#         #ipyplot-html-viewer-toggle-gF4FPnN5kZWyS6b7XSKVix {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gF4FPnN5kZWyS6b7XSKVix {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gF4FPnN5kZWyS6b7XSKVix {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gF4FPnN5kZWyS6b7XSKVix:checked ~ #ipyplot-html-viewer-textarea-gF4FPnN5kZWyS6b7XSKVix {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gF4FPnN5kZWyS6b7XSKVix:checked + #ipyplot-html-viewer-label-gF4FPnN5kZWyS6b7XSKVix:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-gF4FPnN5kZWyS6b7XSKVix">
#         <label id="ipyplot-html-viewer-label-gF4FPnN5kZWyS6b7XSKVix" for="ipyplot-html-viewer-toggle-gF4FPnN5kZWyS6b7XSKVix">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-gF4FPnN5kZWyS6b7XSKVix" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Pgb8YiVvw4b2KpXwjnubvz {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Pgb8YiVvw4b2KpXwjnubvz {
#             width: 900px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz {
#             width: 900px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz img {
#             width: 900px;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Pgb8YiVvw4b2KpXwjnubvz">
#     <div class="ipyplot-placeholder-div-Pgb8YiVvw4b2KpXwjnubvz">
#         <div id="ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz-CMXqtmV6siwWTDsodMGaB9" class="ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz-CMXqtmV6siwWTDsodMGaB9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-Pgb8YiVvw4b2KpXwjnubvz {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Pgb8YiVvw4b2KpXwjnubvz {
#             width: 900px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz {
#             width: 900px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz img {
#             width: 900px;
#         }
#
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Pgb8YiVvw4b2KpXwjnubvz">
#     <div class="ipyplot-placeholder-div-Pgb8YiVvw4b2KpXwjnubvz">
#         <div id="ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz-CMXqtmV6siwWTDsodMGaB9" class="ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Pgb8YiVvw4b2KpXwjnubvz-CMXqtmV6siwWTDsodMGaB9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# Press Enter to continue... Or Q to quit.
#
# How many $ you want to place to your pot ?
#  10
#
#
# You have 10$ available for betting.
# The CPU has 10$ available for betting.
#
#
# Place your bet for the round 1 and turn 1 :
# 3
#
#
# ------------------------------------ TURN 1 ------------------------------------
#
# **PLAYER TURN:**
# For this turn (number 1) a new card has automatically been drawn to the player by the dealer (CPU).
# Here's the card : 5♦.
#     <style>
#         #ipyplot-html-viewer-toggle-54xQrySCRnZAW9BEai43Yj {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-54xQrySCRnZAW9BEai43Yj {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-54xQrySCRnZAW9BEai43Yj {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-54xQrySCRnZAW9BEai43Yj:checked ~ #ipyplot-html-viewer-textarea-54xQrySCRnZAW9BEai43Yj {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-54xQrySCRnZAW9BEai43Yj:checked + #ipyplot-html-viewer-label-54xQrySCRnZAW9BEai43Yj:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-54xQrySCRnZAW9BEai43Yj">
#         <label id="ipyplot-html-viewer-label-54xQrySCRnZAW9BEai43Yj" for="ipyplot-html-viewer-toggle-54xQrySCRnZAW9BEai43Yj">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-54xQrySCRnZAW9BEai43Yj" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-7JwVc2n3rg4B3tf7YppiqZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-7JwVc2n3rg4B3tf7YppiqZ {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-7JwVc2n3rg4B3tf7YppiqZ">
#     <div class="ipyplot-placeholder-div-7JwVc2n3rg4B3tf7YppiqZ">
#         <div id="ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ-C3AkmgFfdpgNhujBeHGoUZ" class="ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ-C3AkmgFfdpgNhujBeHGoUZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-7JwVc2n3rg4B3tf7YppiqZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-7JwVc2n3rg4B3tf7YppiqZ {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-7JwVc2n3rg4B3tf7YppiqZ">
#     <div class="ipyplot-placeholder-div-7JwVc2n3rg4B3tf7YppiqZ">
#         <div id="ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ-C3AkmgFfdpgNhujBeHGoUZ" class="ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7JwVc2n3rg4B3tf7YppiqZ-C3AkmgFfdpgNhujBeHGoUZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# **CPU TURN:**
# A new card has been drawn to the CPU.
# Here's the card : 4♠
#     <style>
#         #ipyplot-html-viewer-toggle-nPFvU6AK3cxf4nNDa76Egy {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nPFvU6AK3cxf4nNDa76Egy {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nPFvU6AK3cxf4nNDa76Egy {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nPFvU6AK3cxf4nNDa76Egy:checked ~ #ipyplot-html-viewer-textarea-nPFvU6AK3cxf4nNDa76Egy {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nPFvU6AK3cxf4nNDa76Egy:checked + #ipyplot-html-viewer-label-nPFvU6AK3cxf4nNDa76Egy:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-nPFvU6AK3cxf4nNDa76Egy">
#         <label id="ipyplot-html-viewer-label-nPFvU6AK3cxf4nNDa76Egy" for="ipyplot-html-viewer-toggle-nPFvU6AK3cxf4nNDa76Egy">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-nPFvU6AK3cxf4nNDa76Egy" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-CtqazSwnXT5HeSKLm8m8yV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-CtqazSwnXT5HeSKLm8m8yV {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-CtqazSwnXT5HeSKLm8m8yV">
#     <div class="ipyplot-placeholder-div-CtqazSwnXT5HeSKLm8m8yV">
#         <div id="ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV-ZAcwfhYsYx6J9ftu7dArYc" class="ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV-ZAcwfhYsYx6J9ftu7dArYc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-CtqazSwnXT5HeSKLm8m8yV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-CtqazSwnXT5HeSKLm8m8yV {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-CtqazSwnXT5HeSKLm8m8yV">
#     <div class="ipyplot-placeholder-div-CtqazSwnXT5HeSKLm8m8yV">
#         <div id="ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV-ZAcwfhYsYx6J9ftu7dArYc" class="ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CtqazSwnXT5HeSKLm8m8yV-ZAcwfhYsYx6J9ftu7dArYc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ----------------------------------------------
# -------------- TURN 1 - RESULTS --------------
# ----------------------------------------------
#
# The PLAYER cards are: ['5♦']
# The PLAYER scores are: [5]
# The PLAYER total score is: 5
#
# The CPU cards are: ['4♠']
# The CPU scores are: [4]
# The CPU total score is: 4
#
# ----------------------------------------------
# ----------------------------------------------
# ----------------------------------------------
#
# Press Enter to continue... Or Q to quit.
#
# ------------------------------------ TURN 2 ------------------------------------
#
# **PLAYER TURN:**
# For this turn (number 2) a new card has automatically been drawn to the player by the dealer (CPU).
# Here's the card : 3♣.
#     <style>
#         #ipyplot-html-viewer-toggle-UkTQcGQdh8QzqhkjYVmFaF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UkTQcGQdh8QzqhkjYVmFaF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UkTQcGQdh8QzqhkjYVmFaF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UkTQcGQdh8QzqhkjYVmFaF:checked ~ #ipyplot-html-viewer-textarea-UkTQcGQdh8QzqhkjYVmFaF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UkTQcGQdh8QzqhkjYVmFaF:checked + #ipyplot-html-viewer-label-UkTQcGQdh8QzqhkjYVmFaF:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-UkTQcGQdh8QzqhkjYVmFaF">
#         <label id="ipyplot-html-viewer-label-UkTQcGQdh8QzqhkjYVmFaF" for="ipyplot-html-viewer-toggle-UkTQcGQdh8QzqhkjYVmFaF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-UkTQcGQdh8QzqhkjYVmFaF" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-jFzmJAtk7xMH4etdi6UpbZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jFzmJAtk7xMH4etdi6UpbZ {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jFzmJAtk7xMH4etdi6UpbZ">
#     <div class="ipyplot-placeholder-div-jFzmJAtk7xMH4etdi6UpbZ">
#         <div id="ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ-RZ8V8kzHvB6uN8hVifNm4h" class="ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ-RZ8V8kzHvB6uN8hVifNm4h">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jFzmJAtk7xMH4etdi6UpbZ">
#         <div id="ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ-L3eEXHuA4PhxdeYcevy6dL" class="ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ-L3eEXHuA4PhxdeYcevy6dL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-jFzmJAtk7xMH4etdi6UpbZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jFzmJAtk7xMH4etdi6UpbZ {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jFzmJAtk7xMH4etdi6UpbZ">
#     <div class="ipyplot-placeholder-div-jFzmJAtk7xMH4etdi6UpbZ">
#         <div id="ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ-RZ8V8kzHvB6uN8hVifNm4h" class="ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ-RZ8V8kzHvB6uN8hVifNm4h">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jFzmJAtk7xMH4etdi6UpbZ">
#         <div id="ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ-L3eEXHuA4PhxdeYcevy6dL" class="ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jFzmJAtk7xMH4etdi6UpbZ-L3eEXHuA4PhxdeYcevy6dL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ----------------------------------------------
# -------------- TURN 2 - RESULTS --------------
# ----------------------------------------------
#
# The PLAYER cards are: ['5♦', '3♣']
# The PLAYER scores are: [5, 3]
# The PLAYER total score is: 8
#
# The CPU cards are: ['4♠']
# The CPU scores are: [4]
# The CPU total score is: 4
#
# ----------------------------------------------
# ----------------------------------------------
# ----------------------------------------------
#
# Press Enter to continue... Or Q to quit.
#
# ------------------------------------ TURN 3 ------------------------------------
#
# **PLAYER TURN:**
# Press 'S' to STOP drawing cards. Any other key to continue drawing cards: S
#
# **CPU TURN:**
# A new card has been drawn to the CPU.
# Here's the card : 2♠
#     <style>
#         #ipyplot-html-viewer-toggle-dR7iWgxmZcnKjJAdEf5w8b {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dR7iWgxmZcnKjJAdEf5w8b {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dR7iWgxmZcnKjJAdEf5w8b {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dR7iWgxmZcnKjJAdEf5w8b:checked ~ #ipyplot-html-viewer-textarea-dR7iWgxmZcnKjJAdEf5w8b {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dR7iWgxmZcnKjJAdEf5w8b:checked + #ipyplot-html-viewer-label-dR7iWgxmZcnKjJAdEf5w8b:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-dR7iWgxmZcnKjJAdEf5w8b">
#         <label id="ipyplot-html-viewer-label-dR7iWgxmZcnKjJAdEf5w8b" for="ipyplot-html-viewer-toggle-dR7iWgxmZcnKjJAdEf5w8b">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-dR7iWgxmZcnKjJAdEf5w8b" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-exVtjhAPB3xXkz5ekXGhzt {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-exVtjhAPB3xXkz5ekXGhzt {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-exVtjhAPB3xXkz5ekXGhzt">
#     <div class="ipyplot-placeholder-div-exVtjhAPB3xXkz5ekXGhzt">
#         <div id="ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt-Nq22e4Dnse2GjNXwcczz5v" class="ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt-Nq22e4Dnse2GjNXwcczz5v">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-exVtjhAPB3xXkz5ekXGhzt">
#         <div id="ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt-bcfAJ3zxGZfAceJedjGCaH" class="ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt-bcfAJ3zxGZfAceJedjGCaH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-exVtjhAPB3xXkz5ekXGhzt {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-exVtjhAPB3xXkz5ekXGhzt {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-exVtjhAPB3xXkz5ekXGhzt">
#     <div class="ipyplot-placeholder-div-exVtjhAPB3xXkz5ekXGhzt">
#         <div id="ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt-Nq22e4Dnse2GjNXwcczz5v" class="ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt-Nq22e4Dnse2GjNXwcczz5v">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-exVtjhAPB3xXkz5ekXGhzt">
#         <div id="ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt-bcfAJ3zxGZfAceJedjGCaH" class="ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-exVtjhAPB3xXkz5ekXGhzt-bcfAJ3zxGZfAceJedjGCaH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ----------------------------------------------
# -------------- TURN 3 - RESULTS --------------
# ----------------------------------------------
#
# The PLAYER cards are: ['5♦', '3♣']
# The PLAYER scores are: [5, 3]
# The PLAYER total score is: 8
#
# The CPU cards are: ['4♠', '2♠']
# The CPU scores are: [4, 2]
# The CPU total score is: 6
#
# ----------------------------------------------
# ----------------------------------------------
# ----------------------------------------------
#
# Press Enter to continue... Or Q to quit.
#
# ------------------------------------ TURN 4 ------------------------------------
#
# **PLAYER TURN:**
#
# **CPU TURN:**
# A new card has been drawn to the CPU.
# Here's the card : Q♣
#     <style>
#         #ipyplot-html-viewer-toggle-JbXS8Vo8jeiVYER8D2DkHq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-JbXS8Vo8jeiVYER8D2DkHq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-JbXS8Vo8jeiVYER8D2DkHq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-JbXS8Vo8jeiVYER8D2DkHq:checked ~ #ipyplot-html-viewer-textarea-JbXS8Vo8jeiVYER8D2DkHq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-JbXS8Vo8jeiVYER8D2DkHq:checked + #ipyplot-html-viewer-label-JbXS8Vo8jeiVYER8D2DkHq:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-JbXS8Vo8jeiVYER8D2DkHq">
#         <label id="ipyplot-html-viewer-label-JbXS8Vo8jeiVYER8D2DkHq" for="ipyplot-html-viewer-toggle-JbXS8Vo8jeiVYER8D2DkHq">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-JbXS8Vo8jeiVYER8D2DkHq" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-LsGRz883AvXed5cr6Bnhus {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LsGRz883AvXed5cr6Bnhus {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LsGRz883AvXed5cr6Bnhus {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LsGRz883AvXed5cr6Bnhus span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LsGRz883AvXed5cr6Bnhus span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LsGRz883AvXed5cr6Bnhus img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-LsGRz883AvXed5cr6Bnhus span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LsGRz883AvXed5cr6Bnhus span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LsGRz883AvXed5cr6Bnhus]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LsGRz883AvXed5cr6Bnhus]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LsGRz883AvXed5cr6Bnhus]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LsGRz883AvXed5cr6Bnhus">
#     <div class="ipyplot-placeholder-div-LsGRz883AvXed5cr6Bnhus">
#         <div id="ipyplot-content-div-LsGRz883AvXed5cr6Bnhus-LeNijoH5J7gdPdwt9xGdW6" class="ipyplot-content-div-LsGRz883AvXed5cr6Bnhus">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LsGRz883AvXed5cr6Bnhus-LeNijoH5J7gdPdwt9xGdW6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LsGRz883AvXed5cr6Bnhus">
#         <div id="ipyplot-content-div-LsGRz883AvXed5cr6Bnhus-5waExaKBrHab7NkoftdZnr" class="ipyplot-content-div-LsGRz883AvXed5cr6Bnhus">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LsGRz883AvXed5cr6Bnhus-5waExaKBrHab7NkoftdZnr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LsGRz883AvXed5cr6Bnhus">
#         <div id="ipyplot-content-div-LsGRz883AvXed5cr6Bnhus-nyPb9gZTShdwyqtfJaJask" class="ipyplot-content-div-LsGRz883AvXed5cr6Bnhus">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LsGRz883AvXed5cr6Bnhus-nyPb9gZTShdwyqtfJaJask">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-LsGRz883AvXed5cr6Bnhus {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
# ...
#             left: 0;
#         }
#
#         div.ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-P6YWzMknFKbuNzBSeWCAXw">
#     <div class="ipyplot-placeholder-div-P6YWzMknFKbuNzBSeWCAXw">
#         <div id="ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw-XEw2GqnFt93VRLtK5ew7Db" class="ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw-XEw2GqnFt93VRLtK5ew7Db">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-P6YWzMknFKbuNzBSeWCAXw">
#         <div id="ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw-nwHyJvmLds5asQGScszWzG" class="ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-P6YWzMknFKbuNzBSeWCAXw-nwHyJvmLds5asQGScszWzG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ----------------------------------------------
# -------------- TURN 3 - RESULTS --------------
# ----------------------------------------------
#
# The PLAYER cards are: ['7♦', 'K♠']
# The PLAYER scores are: [7, 10]
# The PLAYER total score is: 17
#
# The CPU cards are: ['9♥', '4♦']
# The CPU scores are: [9, 4]
# The CPU total score is: 13
#
# ----------------------------------------------
# ----------------------------------------------
# ----------------------------------------------
#
# Press Enter to continue... Or Q to quit.
#
# ------------------------------------ TURN 4 ------------------------------------
#
# **PLAYER TURN:**
#
# **CPU TURN:**
# A new card has been drawn to the CPU.
# Here's the card : 5♣
#     <style>
#         #ipyplot-html-viewer-toggle-G2wbi9kHZBgWHdVYXjTGgM {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-G2wbi9kHZBgWHdVYXjTGgM {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-G2wbi9kHZBgWHdVYXjTGgM {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-G2wbi9kHZBgWHdVYXjTGgM:checked ~ #ipyplot-html-viewer-textarea-G2wbi9kHZBgWHdVYXjTGgM {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-G2wbi9kHZBgWHdVYXjTGgM:checked + #ipyplot-html-viewer-label-G2wbi9kHZBgWHdVYXjTGgM:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-G2wbi9kHZBgWHdVYXjTGgM">
#         <label id="ipyplot-html-viewer-label-G2wbi9kHZBgWHdVYXjTGgM" for="ipyplot-html-viewer-toggle-G2wbi9kHZBgWHdVYXjTGgM">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-G2wbi9kHZBgWHdVYXjTGgM" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-d5xFMp2nj5ZVJa4yMax7Bs {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-d5xFMp2nj5ZVJa4yMax7Bs {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-d5xFMp2nj5ZVJa4yMax7Bs">
#     <div class="ipyplot-placeholder-div-d5xFMp2nj5ZVJa4yMax7Bs">
#         <div id="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-hrkSis6BuJr332vLMaJTCF" class="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-hrkSis6BuJr332vLMaJTCF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-d5xFMp2nj5ZVJa4yMax7Bs">
#         <div id="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-BzFhMNHeQdiQfrw3ZUC9Gn" class="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-BzFhMNHeQdiQfrw3ZUC9Gn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-d5xFMp2nj5ZVJa4yMax7Bs">
#         <div id="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-fTWAQmzUqWdFFHz9bCPduz" class="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-fTWAQmzUqWdFFHz9bCPduz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-d5xFMp2nj5ZVJa4yMax7Bs {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-d5xFMp2nj5ZVJa4yMax7Bs {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-d5xFMp2nj5ZVJa4yMax7Bs">
#     <div class="ipyplot-placeholder-div-d5xFMp2nj5ZVJa4yMax7Bs">
#         <div id="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-hrkSis6BuJr332vLMaJTCF" class="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-hrkSis6BuJr332vLMaJTCF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-d5xFMp2nj5ZVJa4yMax7Bs">
#         <div id="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-BzFhMNHeQdiQfrw3ZUC9Gn" class="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-BzFhMNHeQdiQfrw3ZUC9Gn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-d5xFMp2nj5ZVJa4yMax7Bs">
#         <div id="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-fTWAQmzUqWdFFHz9bCPduz" class="ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-d5xFMp2nj5ZVJa4yMax7Bs-fTWAQmzUqWdFFHz9bCPduz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ----------------------------------------------
# -------------- TURN 4 - RESULTS --------------
# ----------------------------------------------
#
# The PLAYER cards are: ['7♦', 'K♠']
# The PLAYER scores are: [7, 10]
# The PLAYER total score is: 17
#
# The CPU cards are: ['9♥', '4♦', '5♣']
# The CPU scores are: [9, 4, 5]
# The CPU total score is: 18
#
# ----------------------------------------------
# ----------------------------------------------
# ----------------------------------------------
#
# Press Enter to continue... Or Q to quit.
#
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
#
# CPU IS THE WINNER OF THIS ROUND!
# YOU LOST 3$!
#
# The score of the game in the round 2 is:
#
# PLAYER WINS : 1       PLAYER POT: 10
# CPU WINS: 1              CPU POT: 10
# TIES : 0
#
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
#
#
#
#      ^    ^    ^    ^    ^       ^    ^    ^    ^    ^    ^    ^    ^       ^    ^    ^       ^    ^    ^    ^    ^    ^    ^       ^    ^    ^    ^    ^
#     /B\  /R\  /A\  /C\  /E\     /Y\  /O\  /U\  /R\  /S\  /E\  /L\  /F\     /F\  /O\  /R\     /A\  /N\  /O\  /T\  /H\  /E\  /R\     /R\  /O\  /U\  /N\  /D\
#    <___><___><___><___><___>   <___><___><___><___><___><___><___><___>   <___><___><___>   <___><___><___><___><___><___><___>   <___><___><___><___><___>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-089df3541f90> in <module>
#      30
#      31     if len(cards) >0 and game_break == False:
# ---> 32         print_round_winner()
#      33
#      34     round_number += 1
#
# <ipython-input-17-4d2c4c3e0743> in print_round_winner()
#      53     tprint("\n\n\n BRACE YOURSELF FOR ANOTHER ROUND\n\n\n", font="rnd-small")
#      54
# ---> 55     option_quit_game()
#      56
#      57     return None
#
# <ipython-input-10-6ef443894b0e> in option_quit_game()
#       6     global round_break, game_break
#       7
# ----> 8     check = input("\nPress Enter to continue... Or Q to quit. ")
#       9     if check.lower() == 'q':
#      10         round_break = True
#
# /usr/local/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     855                 "raw_input was called, but this frontend does not support input requests."
#     856             )
# --> 857         return self._input_request(str(prompt),
#     858             self._parent_ident,
#     859             self._parent_header,
#
# /usr/local/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     899             except KeyboardInterrupt:
#     900                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 901                 raise KeyboardInterrupt("Interrupted by user") from None
#     902             except Exception as e:
#     903                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
