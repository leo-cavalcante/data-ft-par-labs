# %% [markdown]
# # Web Scraping of "Welcome to the Jungle" for Data Jobs in Paris

# %% [markdown]
# ### Importing librairies and modules

# %%
import requests
import pandas as pd

# %% [markdown]
# ### Welcome to the Jungle website

# %% [markdown]
# Let's effectuate a research filtering with the criterias needed for my seach:
# - Your dream job? --> Data Analyst
# - Where? --> Paris

# %% [markdown]
# Therefore, here's the URL I will need to scrap:

# %%
URL = "https://csekhvms53-3.algolianet.com/1/indexes/*/queries?x-algolia-agent=Algolia%20for%20vanilla%20JavaScript%20(lite)%203.24.12%3Breact-instantsearch%205.3.2%3BJS%20Helper%20(2.28.1)&x-algolia-application-id=CSEKHVMS53&x-algolia-api-key=02f0d440abc99cae37e126886438b266"

# %%
text = """accept: application/json
Accept-Encoding: gzip, deflate, br
Accept-Language: en-GB,en-US;q=0.9,en;q=0.8
Cache-Control: no-cache
Connection: keep-alive
Content-Length: 2049
content-type: application/x-www-form-urlencoded
Host: csekhvms53-3.algolianet.com
Origin: https://www.welcometothejungle.com
Pragma: no-cache
Referer: https://www.welcometothejungle.com/en/jobs?query=data%20analyst&page=1&aroundQuery=Paris%2C%20France&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&sortBy=mostRecent
Sec-Fetch-Dest: empty
Sec-Fetch-Mode: cors
Sec-Fetch-Site: cross-site
User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36"""

# %%
headers = {h[0]:h[1] for x in text.split('\n') if (h := x.split(': '))}
headers
# Out:
# {'accept': 'application/json',
#  'Accept-Encoding': 'gzip, deflate, br',
#  'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
#  'Cache-Control': 'no-cache',
#  'Connection': 'keep-alive',
#  'Content-Length': '2049',
#  'content-type': 'application/x-www-form-urlencoded',
#  'Host': 'csekhvms53-3.algolianet.com',
#  'Origin': 'https://www.welcometothejungle.com',
#  'Pragma': 'no-cache',
#  'Referer': 'https://www.welcometothejungle.com/en/jobs?query=data%20analyst&page=1&aroundQuery=Paris%2C%20France&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&sortBy=mostRecent',
#  'Sec-Fetch-Dest': 'empty',
#  'Sec-Fetch-Mode': 'cors',
#  'Sec-Fetch-Site': 'cross-site',
#  'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}

# %%
# Since it is a POST request, I will need a "data" argument that I will call payload. The website call it "Form Data"
df = pd.DataFrame()
for i in range(8):
    payload = """{"requests":[{"indexName":"wk_cms_jobs_production_published_at_desc","params":"query=data%20analyst&hitsPerPage=30&maxValuesPerFacet=100&page="""+str(i)+"""&restrictSearchableAttributes=%5B%22name%22%2C%22profile%22%2C%22organization.name%22%2C%22office.city%22%2C%22office.district%22%2C%22office.state%22%2C%22office.country%22%2C%22department%22%2C%22profession.name.en%22%2C%22profession.category.en%22%2C%22contract_type_names.en%22%2C%22sectors.name.en%22%2C%22sectors.parent.en%22%5D&highlightPreTag=%3Cais-highlight-0000000000%3E&highlightPostTag=%3C%2Fais-highlight-0000000000%3E&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&aroundPrecision=20000&disableTypoToleranceOnAttributes=%5B%22profile%22%5D&filters=website.reference%3Awttj_fr&facets=%5B%22office.country_code%22%2C%22office.state%22%2C%22office.district%22%2C%22office.location%22%2C%22online%22%2C%22remote%22%2C%22contract_type_names.en%22%2C%22sectors.parent.en%22%2C%22profession.category.en%22%2C%22experience_level_minimum%22%2C%22organization.size.en%22%2C%22language%22%5D&tagFilters=&numericFilters=%5B%22experience_level_minimum%3E%3D0%22%2C%22experience_level_minimum%3C%3D15%22%5D"},{"indexName":"wk_cms_jobs_production_published_at_desc","params":"query=data%20analyst&hitsPerPage=1&maxValuesPerFacet=100&page=0&restrictSearchableAttributes=%5B%22name%22%2C%22profile%22%2C%22organization.name%22%2C%22office.city%22%2C%22office.district%22%2C%22office.state%22%2C%22office.country%22%2C%22department%22%2C%22profession.name.en%22%2C%22profession.category.en%22%2C%22contract_type_names.en%22%2C%22sectors.name.en%22%2C%22sectors.parent.en%22%5D&highlightPreTag=%3Cais-highlight-0000000000%3E&highlightPostTag=%3C%2Fais-highlight-0000000000%3E&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&aroundPrecision=20000&disableTypoToleranceOnAttributes=%5B%22profile%22%5D&filters=website.reference%3Awttj_fr&attributesToRetrieve=%5B%5D&attributesToHighlight=%5B%5D&attributesToSnippet=%5B%5D&tagFilters=&analytics=false&clickAnalytics=false&facets=experience_level_minimum"}]}"""
    response = requests.post(URL, headers=headers, data=payload)
    data = response.json()["results"][0]["hits"]
    df = pd.concat([df, pd.json_normalize(data)])
df
# Out:
#                                                  slug  \
# 0     revenue-strategy-and-business-analyst-h-f_paris
# 1             analyste-conformite_paris_MOONC_WaOlWMA
# 2                        senior-data-strategist_paris
# 3           senior-data-product-manager-h-f-cdi_paris
# 4                        head-of-data-analytics_paris
# ..                                                ...
# 25        business-operations-data-analyst-h-f_clichy
# 26                       operations-analyst-h-f_paris
# 27                 traffic-manager-pre-embauche_paris
# 28  manager-audience-et-performance-h-f_boulogne-b...
# 29                             data-analyst-h-f_paris
#
#                                             name  \
# 0            Data analyst - revenue strategy H/F
# 1                            Analyste Conformité
# 2                 Senior Data Strategist H/F CDI
# 3   Senior Data Product Manager (H/F) - CDI - 🇫🇷
# 4                         Head of Data analytics
# ..                                           ...
# 25        Business Operations Data Analyst (H/F)
# 26                      Operations Analyst (H/F)
# 27            Acquisition Manager (Pré-embauche)
# 28  Responsable Data Analyst Solutions B2B (H/F)
# 29                            Data Analyst (H/F)
#
#                                               profile language  \
# 0   * Tu justifies d’au moins une première expérie...       fr
# 1   Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# 2   Diplômé d’une école d’ingénieur ou de commerce...       fr
# 3   * Issu(e) d’une grande école d’ingénieur ou de...       fr
# 4   **Who are you?**\r\n\r\n*Must-have*\r\n\r\n* 8...       en
# ..                                                ...      ...
# 25  Profil\r\n\r\nVos compétences :\r\n•\tCompéten...       fr
# 26  **About you**\r\n\r\n* You are fluent and have...       en
# 27  - Analytique/ Data-driven : Vous aimez manipul...       fr
# 28  Formation supérieure niveau Bac +5 dans les st...       fr
# 29  Votre expérience et vos qualités :\r\n* Au moi...       fr
#
#                      published_at      reference  \
# 0   2021-02-18T17:10:25.770+01:00  WEDOO_rxbK3b9
# 1   2021-02-18T16:55:59.821+01:00  MOONC_WaOlWMA
# 2   2021-02-18T15:42:48.120+01:00  FABER_973JKVD
# 3   2021-02-18T15:02:01.142+01:00  PAPER_KPZgMa0
# 4   2021-02-18T14:32:21.564+01:00   LUKO_bV70ZAm
# ..                            ...            ...
# 25  2021-01-13T18:28:20.780+01:00  OPENI_1zRZkJM
# 26  2021-01-13T11:01:21.271+01:00  OWKIN_5GamajX
# 27  2021-01-12T18:08:16.849+01:00     IA_GAwe50z
# 28  2021-01-12T13:56:59.140+01:00  SOLOC_z5e0ZR3
# 29  2021-01-12T12:20:21.843+01:00  JOONE_J3b4KJ8
#
#                                               sectors contract_type  \
# 0   [{'name': {'fr': 'Application mobile', 'en': '...     FULL_TIME
# 1   [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...     FULL_TIME
# 2   [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...     FULL_TIME
# 3   [{'name': {'fr': 'Logiciels', 'en': 'Software'...     FULL_TIME
# 4   [{'name': {'fr': 'Intelligence artificielle / ...     FULL_TIME
# ..                                                ...           ...
# 25  [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...     FULL_TIME
# 26  [{'name': {'fr': 'Intelligence artificielle / ...     FULL_TIME
# 27  [{'name': {'fr': 'Digital Marketing / Data Mar...    INTERNSHIP
# 28  [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...     FULL_TIME
# 29  [{'name': {'fr': 'E-commerce', 'en': 'E-commer...     FULL_TIME
#
#     experience_level_minimum          department  ...  \
# 0                        0.5           Enseignes  ...
# 1                        2.0    Customer Service  ...
# 2                        3.0   Marketing Digital  ...
# 3                        2.0  Marketing & Growth  ...
# 4                        7.0           AI & Tech  ...
# ..                       ...                 ...  ...
# 25                       2.0  Direction Générale  ...
# 26                       1.0          Operations  ...
# 27                       1.0                None  ...
# 28                       5.0                None  ...
# 29                       2.0           EXPANSION  ...
#
#    profession_name.fr.Relation client profession_name.en.Customer Service  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
# ..                                ...                                 ...
# 25                                NaN                                 NaN
# 26                                NaN                                 NaN
# 27                                NaN                                 NaN
# 28                                NaN                                 NaN
# 29                                NaN                                 NaN
#
#    profession_name.es.Relación con los clientes  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
#
#    profession_name.cs.Zákaznický servis profession_name.sk.Zákaznícky servis  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ..                                  ...                                  ...
# 25                                  NaN                                  NaN
# 26                                  NaN                                  NaN
# 27                                  NaN                                  NaN
# 28                                  NaN                                  NaN
# 29                                  NaN                                  NaN
#
#    profession_name.fr.Créa profession_name.en.Design  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
# ..                     ...                       ...
# 25                     NaN                       NaN
# 26                     NaN                       NaN
# 27                     NaN                       NaN
# 28                     NaN                       NaN
# 29                     NaN                       NaN
#
#    profession_name.es.Diseño y creatividad profession_name.cs.Design  \
# 0                                      NaN                       NaN
# 1                                      NaN                       NaN
# 2                                      NaN                       NaN
# 3                                      NaN                       NaN
# 4                                      NaN                       NaN
# ..                                     ...                       ...
# 25                                     NaN                       NaN
# 26                                     NaN                       NaN
# 27                                     NaN                       NaN
# 28                                     NaN                       NaN
# 29                                     NaN                       NaN
#
#    profession_name.sk.Dizajn
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
#
# [240 rows x 193 columns]

# %%
df = df.reset_index()

# %%
df.drop(columns="index", axis=1, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-ca2bcbf874fd> in <module>
# ----> 1 df.drop(columns="index", axis=1, inplace=True)
#       2 df
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4185                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4186             else:
# -> 4187                 new_axis = axis.drop(labels, errors=errors)
#    4188             result = self.reindex(**{axis_name: new_axis})
#    4189
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %% [markdown]
# ## Understanding the data

# %%
df.shape
# Out:
# (240, 193)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Columns: 193 entries, slug to profession_name.sk.Dizajn
# dtypes: float64(3), object(190)
# memory usage: 362.0+ KB

# %%
df.iloc[:,10:30]
# Out:
#        remote objectID website.reference  organization.name  \
# 0          no   476838           wttj_fr          Wedoogift
# 1          no   493447           wttj_fr           Mooncard
# 2    punctual   491884           wttj_fr         FABERNOVEL
# 3     partial   493329           wttj_fr          papernest
# 4    fulltime   462020           wttj_fr               Luko
# ..        ...      ...               ...                ...
# 235   partial   423932           wttj_fr             OpenIP
# 236   partial   462834           wttj_fr              Owkin
# 237   partial   462485           wttj_fr  Impulse Analytics
# 238  punctual   462215           wttj_fr            Solocal
# 239        no   462174           wttj_fr              Joone
#
#             organization.slug organization.reference  \
# 0                   wedoogift                pk8Ze3K
# 1                    mooncard                rYxo7wR
# 2                  fabernovel                lMW728Z
# 3                  souscritoo                 3jRk35
# 4    la-societe-demain-es-sas                QaZy5Kz
# ..                        ...                    ...
# 235                    openip                Jwb2Rp4
# 236                     owkin                JoKemDV
# 237         impulse-analytics                xy06y4m
# 238                   solocal                PYLWlqk
# 239                     joone                Jywlm5V
#
#            organization.size.fr             organization.size.en  \
# 0      Entre 50 et 250 salariés     Between 50 and 250 employees
# 1       Entre 15 et 50 salariés      Between 15 and 50 employees
# 2    Entre 250 et 2000 salariés  Between 250 and 2,000 employees
# 3    Entre 250 et 2000 salariés  Between 250 and 2,000 employees
# 4      Entre 50 et 250 salariés     Between 50 and 250 employees
# ..                          ...                              ...
# 235    Entre 50 et 250 salariés     Between 50 and 250 employees
# 236    Entre 50 et 250 salariés     Between 50 and 250 employees
# 237               < 15 salariés                   < 15 employees
# 238             > 2000 salariés                > 2,000 employees
# 239    Entre 50 et 250 salariés     Between 50 and 250 employees
#
#            organization.size.es         organization.size.cs  \
# 0      Entre 50 y 250 empleados     Od 50 do 250 zaměstnanců
# 1       Entre 15 y 50 empleados      Od 15 do 50 zaměstnanců
# 2    Entre 250 y 2000 empleados  Od 250 do 2 000 zaměstnanců
# 3    Entre 250 y 2000 empleados  Od 250 do 2 000 zaměstnanců
# 4      Entre 50 y 250 empleados     Od 50 do 250 zaměstnanců
# ..                          ...                          ...
# 235    Entre 50 y 250 empleados     Od 50 do 250 zaměstnanců
# 236    Entre 50 y 250 empleados     Od 50 do 250 zaměstnanců
# 237              < 15 empleados             < 15 zaměstnanců
# 238            > 2000 empleados          > 2 000 zaměstnanců
# 239    Entre 50 y 250 empleados     Od 50 do 250 zaměstnanců
#
#              organization.size.sk  \
# 0       Od 50 do 250 zamestnancov
# 1        Od 15 do 50 zamestnancov
# 2    Od 250 do 2 000 zamestnancov
# 3    Od 250 do 2 000 zamestnancov
# 4       Od 50 do 250 zamestnancov
# ..                            ...
# 235     Od 50 do 250 zamestnancov
# 236     Od 50 do 250 zamestnancov
# 237             < 15 zamestnancov
# 238          > 2 000 zamestnancov
# 239     Od 50 do 250 zamestnancov
#
#                                  organization.logo.url  \
# 0    https://cdn-images.welcometothejungle.com/L45Y...
# 1    https://cdn-images.welcometothejungle.com/asm3...
# 2    https://cdn-images.welcometothejungle.com/m0Kh...
# 3    https://cdn-images.welcometothejungle.com/-0Pn...
# 4    https://cdn-images.welcometothejungle.com/lN3z...
# ..                                                 ...
# 235  https://cdn-images.welcometothejungle.com/gE3p...
# 236  https://cdn-images.welcometothejungle.com/T7kR...
# 237  https://cdn-images.welcometothejungle.com/592n...
# 238  https://cdn-images.welcometothejungle.com/J2Iu...
# 239  https://cdn-images.welcometothejungle.com/BdVn...
#
#                            organization.logo.thumb.url organization.labels  \
# 0    https://cdn-images.welcometothejungle.com/OzE5...                  []
# 1    https://cdn-images.welcometothejungle.com/LcAQ...                  []
# 2    https://cdn-images.welcometothejungle.com/vD1c...                  []
# 3    https://cdn-images.welcometothejungle.com/YNpZ...                  []
# 4    https://cdn-images.welcometothejungle.com/VCOb...                  []
# ..                                                 ...                 ...
# 235  https://cdn-images.welcometothejungle.com/4q8o...                 NaN
# 236  https://cdn-images.welcometothejungle.com/_in_...                 NaN
# 237  https://cdn-images.welcometothejungle.com/JQXv...                  []
# 238  https://cdn-images.welcometothejungle.com/ZGwY...                 NaN
# 239  https://cdn-images.welcometothejungle.com/u3CS...                 NaN
#
#                        organization.cover_image.fr.url  \
# 0    https://cdn-images.welcometothejungle.com/1Cl1...
# 1    https://cdn-images.welcometothejungle.com/jFyZ...
# 2    https://cdn-images.welcometothejungle.com/ujwk...
# 3    https://cdn-images.welcometothejungle.com/2oYK...
# 4    https://cdn-images.welcometothejungle.com/TY_0...
# ..                                                 ...
# 235  https://cdn-images.welcometothejungle.com/fjbY...
# 236  https://cdn-images.welcometothejungle.com/j8FW...
# 237  https://cdn-images.welcometothejungle.com/J4NL...
# 238  https://cdn-images.welcometothejungle.com/Lf4y...
# 239  https://cdn-images.welcometothejungle.com/juJ8...
#
#                  organization.cover_image.fr.large.url  \
# 0    https://cdn-images.welcometothejungle.com/UMzs...
# 1    https://cdn-images.welcometothejungle.com/iFpL...
# 2    https://cdn-images.welcometothejungle.com/syX1...
# 3    https://cdn-images.welcometothejungle.com/HdhL...
# 4    https://cdn-images.welcometothejungle.com/5VaO...
# ..                                                 ...
# 235  https://cdn-images.welcometothejungle.com/l1ea...
# 236  https://cdn-images.welcometothejungle.com/LELF...
# 237  https://cdn-images.welcometothejungle.com/raGh...
# 238  https://cdn-images.welcometothejungle.com/3ofl...
# 239  https://cdn-images.welcometothejungle.com/NXrl...
#
#                  organization.cover_image.fr.thumb.url  \
# 0    https://cdn-images.welcometothejungle.com/fhyz...
# 1    https://cdn-images.welcometothejungle.com/TOQn...
# 2    https://cdn-images.welcometothejungle.com/NTeM...
# 3    https://cdn-images.welcometothejungle.com/2ecN...
# 4    https://cdn-images.welcometothejungle.com/nbqR...
# ..                                                 ...
# 235  https://cdn-images.welcometothejungle.com/p6-O...
# 236  https://cdn-images.welcometothejungle.com/UvSt...
# 237  https://cdn-images.welcometothejungle.com/xRFr...
# 238  https://cdn-images.welcometothejungle.com/9QhH...
# 239  https://cdn-images.welcometothejungle.com/4-kd...
#
#                  organization.cover_image.fr.small.url  \
# 0    https://cdn-images.welcometothejungle.com/ek2g...
# 1    https://cdn-images.welcometothejungle.com/CpvJ...
# 2    https://cdn-images.welcometothejungle.com/LYKC...
# 3    https://cdn-images.welcometothejungle.com/XqcC...
# 4    https://cdn-images.welcometothejungle.com/J5YA...
# ..                                                 ...
# 235  https://cdn-images.welcometothejungle.com/6fEV...
# 236  https://cdn-images.welcometothejungle.com/A0J7...
# 237  https://cdn-images.welcometothejungle.com/rYZj...
# 238  https://cdn-images.welcometothejungle.com/V6wu...
# 239  https://cdn-images.welcometothejungle.com/oboP...
#
#                        organization.cover_image.en.url  \
# 0    https://cdn-images.welcometothejungle.com/1Cl1...
# 1    https://cdn-images.welcometothejungle.com/jFyZ...
# 2    https://cdn-images.welcometothejungle.com/epXQ...
# 3    https://cdn-images.welcometothejungle.com/WTCm...
# 4    https://cdn-images.welcometothejungle.com/TY_0...
# ..                                                 ...
# 235  https://cdn-images.welcometothejungle.com/fjbY...
# 236  https://cdn-images.welcometothejungle.com/atyt...
# 237  https://cdn-images.welcometothejungle.com/J4NL...
# 238  https://cdn-images.welcometothejungle.com/Lf4y...
# 239  https://cdn-images.welcometothejungle.com/juJ8...
#
#                  organization.cover_image.en.large.url
# 0    https://cdn-images.welcometothejungle.com/UMzs...
# 1    https://cdn-images.welcometothejungle.com/iFpL...
# 2    https://cdn-images.welcometothejungle.com/tJmJ...
# 3    https://cdn-images.welcometothejungle.com/Q9OD...
# 4    https://cdn-images.welcometothejungle.com/5VaO...
# ..                                                 ...
# 235  https://cdn-images.welcometothejungle.com/l1ea...
# 236  https://cdn-images.welcometothejungle.com/s88z...
# 237  https://cdn-images.welcometothejungle.com/raGh...
# 238  https://cdn-images.welcometothejungle.com/3ofl...
# 239  https://cdn-images.welcometothejungle.com/NXrl...
#
# [240 rows x 20 columns]

# %%
df.describe(include="all")
# Out:
#                       slug          name profile language  \
# count                  240           240     225      240
# unique                 226           215     216        2
# top     data-analyst_paris  Data Analyst               fr
# freq                    11            13       5      169
# mean                   NaN           NaN     NaN      NaN
# std                    NaN           NaN     NaN      NaN
# min                    NaN           NaN     NaN      NaN
# 25%                    NaN           NaN     NaN      NaN
# 50%                    NaN           NaN     NaN      NaN
# 75%                    NaN           NaN     NaN      NaN
# max                    NaN           NaN     NaN      NaN
#
#                          published_at   reference  \
# count                             240         240
# unique                            240         240
# top     2021-02-18T09:00:04.499+01:00  RF_3RkAGPm
# freq                                1           1
# mean                              NaN         NaN
# std                               NaN         NaN
# min                               NaN         NaN
# 25%                               NaN         NaN
# 50%                               NaN         NaN
# 75%                               NaN         NaN
# max                               NaN         NaN
#
#                                                   sectors contract_type  \
# count                                                 240           240
# unique                                                132             5
# top     [{'name': {'fr': 'FinTech / InsurTech', 'en': ...     FULL_TIME
# freq                                                    9           178
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#         experience_level_minimum department  ...  \
# count                 240.000000        127  ...
# unique                       NaN         73  ...
# top                          NaN       Data  ...
# freq                         NaN         12  ...
# mean                    1.460417        NaN  ...
# std                     1.761839        NaN  ...
# min                     0.000000        NaN  ...
# 25%                     0.000000        NaN  ...
# 50%                     0.750000        NaN  ...
# 75%                     3.000000        NaN  ...
# max                    10.000000        NaN  ...
#
#        profession_name.fr.Relation client profession_name.en.Customer Service  \
# count                                   2                                   2
# unique                                  1                                   1
# top                      Customer Success                    Customer Success
# freq                                    2                                   2
# mean                                  NaN                                 NaN
# std                                   NaN                                 NaN
# min                                   NaN                                 NaN
# 25%                                   NaN                                 NaN
# 50%                                   NaN                                 NaN
# 75%                                   NaN                                 NaN
# max                                   NaN                                 NaN
#
#        profession_name.es.Relación con los clientes  \
# count                                             2
# unique                                            1
# top                               Éxito del cliente
# freq                                              2
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#        profession_name.cs.Zákaznický servis  \
# count                                     2
# unique                                    1
# top                        Customer Success
# freq                                      2
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#        profession_name.sk.Zákaznícky servis profession_name.fr.Créa  \
# count                                     2                       1
# unique                                    1                       1
# top                        Customer Success               UI Design
# freq                                      2                       1
# mean                                    NaN                     NaN
# std                                     NaN                     NaN
# min                                     NaN                     NaN
# 25%                                     NaN                     NaN
# 50%                                     NaN                     NaN
# 75%                                     NaN                     NaN
# max                                     NaN                     NaN
#
#        profession_name.en.Design profession_name.es.Diseño y creatividad  \
# count                          1                                       1
# unique                         1                                       1
# top                    UI Design                               Diseño UI
# freq                           1                                       1
# mean                         NaN                                     NaN
# std                          NaN                                     NaN
# min                          NaN                                     NaN
# 25%                          NaN                                     NaN
# 50%                          NaN                                     NaN
# 75%                          NaN                                     NaN
# max                          NaN                                     NaN
#
#        profession_name.cs.Design profession_name.sk.Dizajn
# count                          1                         1
# unique                         1                         1
# top                    UI Design                 UI Design
# freq                           1                         1
# mean                         NaN                       NaN
# std                          NaN                       NaN
# min                          NaN                       NaN
# 25%                          NaN                       NaN
# 50%                          NaN                       NaN
# 75%                          NaN                       NaN
# max                          NaN                       NaN
#
# [11 rows x 193 columns]

# %% [markdown]
# # Data Cleaning

# %%
# Dropping all rows and columns that are filled with NA results:
df.dropna(axis=0, how="all")
df.dropna(axis=1, how="all")
df.shape
# Out:
# (240, 193)

# %% [markdown]
# ### Cleaning columns columns that show duplicated content in other languages other than English:

# %%
# Identifying all the columns :
col = []
for language in [".cs", ".es", ".fr", ".sk"]:
    col += [c for c in df.columns if language in c]
col
# Out:
# ['organization.size.cs',
#  'organization.cover_image.cs.url',
#  'organization.cover_image.cs.large.url',
#  'organization.cover_image.cs.thumb.url',
#  'organization.cover_image.cs.small.url',
#  'sectors_name.cs',
#  'contract_type_names.cs',
#  'profession.name.cs',
#  'profession.category.cs',
#  'profession_name.cs.Business',
#  '_highlightResult.contract_type_names.cs.value',
#  '_highlightResult.contract_type_names.cs.matchLevel',
#  '_highlightResult.contract_type_names.cs.matchedWords',
#  '_highlightResult.profession.name.cs.value',
#  '_highlightResult.profession.name.cs.matchLevel',
#  '_highlightResult.profession.name.cs.matchedWords',
#  '_highlightResult.profession.category.cs.value',
#  '_highlightResult.profession.category.cs.matchLevel',
#  '_highlightResult.profession.category.cs.matchedWords',
#  'profession_name.cs.Audit / Finance / Pojišťovnictví',
#  'profession_name.cs.Tech',
#  '_highlightResult.profession.name.cs.fullyHighlighted',
#  'profession_name.cs.Marketing a komunikace',
#  'profession_name.cs.Podpora',
#  'profession_name.cs.Consulting',
#  'profession_name.cs.Zákaznický servis',
#  'profession_name.cs.Design',
#  'organization.size.es',
#  'organization.cover_image.es.url',
#  'organization.cover_image.es.large.url',
#  'organization.cover_image.es.thumb.url',
#  'organization.cover_image.es.small.url',
#  'sectors_name.es',
#  'contract_type_names.es',
#  'profession.name.es',
#  'profession.category.es',
#  'profession_name.es.Negocios',
#  '_highlightResult.contract_type_names.es.value',
#  '_highlightResult.contract_type_names.es.matchLevel',
#  '_highlightResult.contract_type_names.es.matchedWords',
#  '_highlightResult.profession.name.es.value',
#  '_highlightResult.profession.name.es.matchLevel',
#  '_highlightResult.profession.name.es.matchedWords',
#  '_highlightResult.profession.category.es.value',
#  '_highlightResult.profession.category.es.matchLevel',
#  '_highlightResult.profession.category.es.matchedWords',
#  'profession_name.es.Auditoría/Finanzas/Seguros',
#  'profession_name.es.Tecnología',
#  'profession_name.es.Marketing/Comunicación',
#  'profession_name.es.Servicios generales',
#  'profession_name.es.Asesoría',
#  'profession_name.es.Relación con los clientes',
#  'profession_name.es.Diseño y creatividad',
#  'organization.size.fr',
#  'organization.cover_image.fr.url',
#  'organization.cover_image.fr.large.url',
#  'organization.cover_image.fr.thumb.url',
#  'organization.cover_image.fr.small.url',
#  'sectors_name.fr',
#  'contract_type_names.fr',
#  'profession.name.fr',
#  'profession.category.fr',
#  'profession_name.fr.Business',
#  '_highlightResult.contract_type_names.fr.value',
#  '_highlightResult.contract_type_names.fr.matchLevel',
#  '_highlightResult.contract_type_names.fr.matchedWords',
#  '_highlightResult.profession.name.fr.value',
#  '_highlightResult.profession.name.fr.matchLevel',
#  '_highlightResult.profession.name.fr.matchedWords',
#  '_highlightResult.profession.category.fr.value',
#  '_highlightResult.profession.category.fr.matchLevel',
#  '_highlightResult.profession.category.fr.matchedWords',
#  'profession_name.fr.Audit / Finance / Assurance',
#  'profession_name.fr.Tech',
#  '_highlightResult.profession.name.fr.fullyHighlighted',
#  'profession_name.fr.Marketing / Communication',
#  'profession_name.fr.Support',
#  'profession_name.fr.Conseil',
#  'profession_name.fr.Relation client',
#  'profession_name.fr.Créa',
#  'organization.size.sk',
#  'organization.cover_image.sk.url',
#  'organization.cover_image.sk.large.url',
#  'organization.cover_image.sk.thumb.url',
#  'organization.cover_image.sk.small.url',
#  'sectors_name.sk',
#  'contract_type_names.sk',
#  'profession.name.sk',
#  'profession.category.sk',
#  'profession_name.sk.Obchod',
#  '_highlightResult.contract_type_names.sk.value',
#  '_highlightResult.contract_type_names.sk.matchLevel',
#  '_highlightResult.contract_type_names.sk.matchedWords',
#  '_highlightResult.profession.name.sk.value',
#  '_highlightResult.profession.name.sk.matchLevel',
#  '_highlightResult.profession.name.sk.matchedWords',
#  '_highlightResult.profession.category.sk.value',
#  '_highlightResult.profession.category.sk.matchLevel',
#  '_highlightResult.profession.category.sk.matchedWords',
#  'profession_name.sk.Audit / Financie / Poisťovníctvo',
#  'profession_name.sk.Technológie',
#  '_highlightResult.profession.name.sk.fullyHighlighted',
#  'profession_name.sk.Marketing / Komunikácia',
#  'profession_name.sk.Podpora',
#  'profession_name.sk.Poradenstvo',
#  'profession_name.sk.Zákaznícky servis',
#  'profession_name.sk.Dizajn']

# %%
len(col)
# Out:
# 107

# %%
df.drop(axis=1, columns=col, inplace=True)
df.shape
# Out:
# (240, 86)

# %%
# Printing the new columns of our DataFrame
col = [c for c in df.columns]
col
# Out:
# ['slug',
#  'name',
#  'profile',
#  'language',
#  'published_at',
#  'reference',
#  'sectors',
#  'contract_type',
#  'experience_level_minimum',
#  'department',
#  'remote',
#  'objectID',
#  'website.reference',
#  'organization.name',
#  'organization.slug',
#  'organization.reference',
#  'organization.size.en',
#  'organization.logo.url',
#  'organization.logo.thumb.url',
#  'organization.labels',
#  'organization.cover_image.en.url',
#  'organization.cover_image.en.large.url',
#  'organization.cover_image.en.thumb.url',
#  'organization.cover_image.en.small.url',
#  'organization.website_organization.slug',
#  'sectors_name.en',
#  'contract_type_names.en',
#  'office.city',
#  'office.district',
#  'office.state',
#  'office.country',
#  'office.country_code',
#  'profession.name.en',
#  'profession.category.en',
#  'profession_name.en.Business',
#  '_geoloc.lat',
#  '_geoloc.lng',
#  '_highlightResult.name.value',
#  '_highlightResult.name.matchLevel',
#  '_highlightResult.name.fullyHighlighted',
#  '_highlightResult.name.matchedWords',
#  '_highlightResult.profile.value',
#  '_highlightResult.profile.matchLevel',
#  '_highlightResult.profile.fullyHighlighted',
#  '_highlightResult.profile.matchedWords',
#  '_highlightResult.organization.name.value',
#  '_highlightResult.organization.name.matchLevel',
#  '_highlightResult.organization.name.matchedWords',
#  '_highlightResult.sectors',
#  '_highlightResult.contract_type_names.en.value',
#  '_highlightResult.contract_type_names.en.matchLevel',
#  '_highlightResult.contract_type_names.en.matchedWords',
#  '_highlightResult.office.city.value',
#  '_highlightResult.office.city.matchLevel',
#  '_highlightResult.office.city.matchedWords',
#  '_highlightResult.office.district.value',
#  '_highlightResult.office.district.matchLevel',
#  '_highlightResult.office.district.matchedWords',
#  '_highlightResult.office.state.value',
#  '_highlightResult.office.state.matchLevel',
#  '_highlightResult.office.state.matchedWords',
#  '_highlightResult.office.country.value',
#  '_highlightResult.office.country.matchLevel',
#  '_highlightResult.office.country.matchedWords',
#  '_highlightResult.office.country_code.value',
#  '_highlightResult.office.country_code.matchLevel',
#  '_highlightResult.office.country_code.matchedWords',
#  '_highlightResult.department.value',
#  '_highlightResult.department.matchLevel',
#  '_highlightResult.department.matchedWords',
#  '_highlightResult.profession.name.en.value',
#  '_highlightResult.profession.name.en.matchLevel',
#  '_highlightResult.profession.name.en.matchedWords',
#  '_highlightResult.profession.category.en.value',
#  '_highlightResult.profession.category.en.matchLevel',
#  '_highlightResult.profession.category.en.matchedWords',
#  'profession_name.en.Audit / Finance / Insurance',
#  'profession_name.en.Tech',
#  '_highlightResult.profession.name.en.fullyHighlighted',
#  'profession_name.en.Marketing / Communications',
#  'profession_name.en.Support Roles',
#  'profession_name.en.Consulting',
#  '_highlightResult.department.fullyHighlighted',
#  '_highlightResult.organization.name.fullyHighlighted',
#  'profession_name.en.Customer Service',
#  'profession_name.en.Design']

# %% [markdown]
# ### Droping all the "Organization" columns that don't interest me:

# %%
df.iloc[:,10:20]
# Out:
#        remote objectID website.reference  organization.name  \
# 0          no   476838           wttj_fr          Wedoogift
# 1          no   493447           wttj_fr           Mooncard
# 2    punctual   491884           wttj_fr         FABERNOVEL
# 3     partial   493329           wttj_fr          papernest
# 4    fulltime   462020           wttj_fr               Luko
# ..        ...      ...               ...                ...
# 235   partial   423932           wttj_fr             OpenIP
# 236   partial   462834           wttj_fr              Owkin
# 237   partial   462485           wttj_fr  Impulse Analytics
# 238  punctual   462215           wttj_fr            Solocal
# 239        no   462174           wttj_fr              Joone
#
#             organization.slug organization.reference  \
# 0                   wedoogift                pk8Ze3K
# 1                    mooncard                rYxo7wR
# 2                  fabernovel                lMW728Z
# 3                  souscritoo                 3jRk35
# 4    la-societe-demain-es-sas                QaZy5Kz
# ..                        ...                    ...
# 235                    openip                Jwb2Rp4
# 236                     owkin                JoKemDV
# 237         impulse-analytics                xy06y4m
# 238                   solocal                PYLWlqk
# 239                     joone                Jywlm5V
#
#                 organization.size.en  \
# 0       Between 50 and 250 employees
# 1        Between 15 and 50 employees
# 2    Between 250 and 2,000 employees
# 3    Between 250 and 2,000 employees
# 4       Between 50 and 250 employees
# ..                               ...
# 235     Between 50 and 250 employees
# 236     Between 50 and 250 employees
# 237                   < 15 employees
# 238                > 2,000 employees
# 239     Between 50 and 250 employees
#
#                                  organization.logo.url  \
# 0    https://cdn-images.welcometothejungle.com/L45Y...
# 1    https://cdn-images.welcometothejungle.com/asm3...
# 2    https://cdn-images.welcometothejungle.com/m0Kh...
# 3    https://cdn-images.welcometothejungle.com/-0Pn...
# 4    https://cdn-images.welcometothejungle.com/lN3z...
# ..                                                 ...
# 235  https://cdn-images.welcometothejungle.com/gE3p...
# 236  https://cdn-images.welcometothejungle.com/T7kR...
# 237  https://cdn-images.welcometothejungle.com/592n...
# 238  https://cdn-images.welcometothejungle.com/J2Iu...
# 239  https://cdn-images.welcometothejungle.com/BdVn...
#
#                            organization.logo.thumb.url organization.labels
# 0    https://cdn-images.welcometothejungle.com/OzE5...                  []
# 1    https://cdn-images.welcometothejungle.com/LcAQ...                  []
# 2    https://cdn-images.welcometothejungle.com/vD1c...                  []
# 3    https://cdn-images.welcometothejungle.com/YNpZ...                  []
# 4    https://cdn-images.welcometothejungle.com/VCOb...                  []
# ..                                                 ...                 ...
# 235  https://cdn-images.welcometothejungle.com/4q8o...                 NaN
# 236  https://cdn-images.welcometothejungle.com/_in_...                 NaN
# 237  https://cdn-images.welcometothejungle.com/JQXv...                  []
# 238  https://cdn-images.welcometothejungle.com/ZGwY...                 NaN
# 239  https://cdn-images.welcometothejungle.com/u3CS...                 NaN
#
# [240 rows x 10 columns]
