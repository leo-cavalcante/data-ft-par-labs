207aa4dbc2b2b77b5d22fa62d0571b-1613660858-1800-Afogj34pFTVwmoFy8yRvMyYMSb8M5O9tgPgrHx5RkA319TJDXV4d3cNuleb1ovMxoEoMv9uIzsZ4JmMzhwsVzoHY2KbpwPHRZ+Nflivl0dXrgLQshdE7w8vgH/jjGL2TeTgd+oruGwmsltlBqHi7rU/hkJHmivOrNbv5QwcDsiDQrKCp23yd2rinQ4uo8bBL6w==; _gid=GA1.2.1247870808.1613660858; _gat=1; OptanonConsent=isIABGlobal=false&datestamp=Thu+Feb+18+2021+16%3A07%3A39+GMT%2B0100+(Central+European+Standard+Time)&version=6.12.0&hosts=&consentId=6768f35d-a203-44ba-9479-3adfcab03b5b&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CSTACK42%3A1&geolocation=FR%3BIDF&AwaitingReconsent=false; _ga=GA1.1.1553445643.1613471833; _ga_ZJHK1N3D75=GS1.1.1613660858.4.1.1613660876.42
pragma: no-cache
referer: https://www.vinted.fr/vetements?catalog[]=1918&time=1613660855&page=2
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36
x-csrf-token: TgXCRPdrzWqX4tfFeFtAFUFFV/VFDgBG7X0ruFNlwZQcFJM7CnkWsCjBf5CLQXUUbN22jFXq7IOACrKlp2ar+Q=="""

# %%
headers = {h[0]:h[1] for x in text.split('\n') if (h := x.split(': '))}
headers
# Out:
# {'accept': 'application/json, text/plain, */*',
#  'accept-encoding': 'gzip, deflate, br',
#  'accept-language': 'fr',
#  'cache-control': 'no-cache',
# ...

# %%
response = requests.get(URL, headers=headers)
response
# Out:
# <Response [200]>

# %%
data = response.json()["items"]
data
# Out:
# [{'id': 894763029,
#   'title': 'Vaso vetro',
#   'brand_id': 321073,
#   'size_id': None,
#   'status_id': 2,
#   'disposal_conditions': 4,
#   'user_id': 52620806,
#   'owner_id': None,
#   'country_id': 18,
#   'catalog_id': 1940,
#   'color1_id': 7,
#   'color2_id': 12,
#   'package_size_id': 9,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 3,
#   'favourite_count': 8,
#   'view_count': 45,
#   'moderation_status': 0,
#   'last_push_up_at': '2021-02-18T15:53:11+01:00',
#   'description': "Come nuovo usato pochissimo e sempre per esposizione mai con acqua all'interno. ",
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '',
#   'brand': 'Sempre',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
# ...

# %%
df_final = pd.json_normalize(data)
df_final
# Out:
#            id                                              title  brand_id  \
# 0   894763029                                         Vaso vetro    321073
# 1   909827164                                      Coussin amour     80824
# 2   893981815        Parure housse de couette neuf , 100 % coton      4143
# 3   901887627         Livre de les jumelles mènent le jeu tome 6         1
# 4   903897124  💓 Magnifique  plat signé Longwy thème coquelic...    734813
# 5   901624228                          No hear, no speak, no see     80824
# 6   900115436                      Le ventre plat, c est facile          1
# 7   897092496                   Specchio artigianale pezzo unico   4146160
# 8   910501179                                    2 drap de bain          1
# 9   910298594       Cadre-miroir avec des decorations de fleurs        573
# 10  904265817                   Joli vase ancien dit George Sand       573
# ...

# %%
for i in [2, 3, 4, 5, 6]:
    URL = "https://www.vinted.fr/api/v2/items?catalog_ids=1918&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page="+str(i)+"&per_page=24&time=1613472454&search_session_id=d9bb6071-1852-4bb4-87e0-95848788cf02"
    #print(URL)
    headers.update({'referer': 'https://www.vinted.fr/vetements?catalog[]=1918&time=1613472454&page='+str(i)})
    #print(headers['referer'])
    response = requests.get(URL, headers=headers)
    data = response.json()["items"]
    df = pd.json_normalize(data)
    df_final = pd.concat([df_final, df])
df_final

# %%
check = list(set(df_final.id))
check

# %%
len(check)
