# %%
import requests
import pandas as pd

# %%
URL = "https://www.vinted.fr/api/v2/items?catalog_ids=1918&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page=1&per_page=24&time=1613475699&search_session_id=d9bb6071-1852-4bb4-87e0-95848788cf02"

# %%
text = """accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: fr
cache-control: no-cache
cookie: __cfduid=d69fa43e7997998c5457bc30c056fc2281613471817; anon_id=6197135a-6861-446c-b004-c8a831cf02f8; G_ENABLED_IDPS=google; OptanonAlertBoxClosed=2021-02-16T10:37:03.550Z; eupubconsent-v2=CPBtEMIPBtEMIAcABBENBNCsAP_AAH_AAChQGXNf_X9fb2vj-_5999t0eY1f9_63t-wzjgeNs-8NyZ_X_J4Xt2MyvB34pqYKmR4EunLBAQdlHGHcTQgAwIkVqTLsYk2MjzNKJ7JEilMbe2dYGH9vn8XT-ZKY70-s___7v3-_____7pAy4AAAgAICAEABQIAAgCAAAAAAIAAAAAAAAwMAggAACAGIAAAIggAAACABABAADAAAIAAAAAAAAACAAAIAAAAAAAAAAAAAAAAARAAAAALAgAAAAAABAAAAAABABAgAgAMCAgAYACMAICAQBOAAKABwAHgAXAA-AC0AHwASQAxAB_AEUAJEAXwAzQBtADiAHIAOcAdQA_wCBgEHAIuAT8AoYBhAEPgI9ASsAm0BYQC0AF0ALqAXaAvIBiADFgGQgMoCQSQAEAALgAoACoAGQAOAAeABAACIAFQANAAeQBDAEQAJgAT4AqgCsAFgALgAbwA5gB6AEIAIaARABEgCOAEsAJoAUoAtwBhgDIAGXANQA1QBsgDvAHsAPiAfYB-gEYAI0ARwAlIBSwCrgFzAL8AYoA1gBtADcAG8APQAfIBDYCLwEiAJiATKAmwBOwChwFIgLFAWwAuQBd4DAgGDAMJAYaAw8BkQDJAGThgBgACwALgBJADEANIAaoA4gDZAHUAUOAvoBkYaA4ACoAKwAXABDADIAGWANQAbIA_-AC0AHIAPwAggBdAC-AGQANAAfwBFACRAFmAL4AYQAywBmgDSAGqANoAcQA5ABzgDqAHcAQAAgcBBwEIAIiARcAm0BPgE_..._AB_gEYAI4ASkAoYBV4C0ALSAXMAvwBigDaAHUAPQAkEBIgCVAE2AKaAWKAtEBbAC4AFyALtAYeAxIBkQDJyQBoAAQADgALgAhAByAF8AMgAkQBcgC-AGWANQAbQA7gCEgFQALqAa8A3gB9gErAJtAUmAsoBfQDFiUCwABAACwAKAAZAA4ACIAGIAPAAiABMACqAFwAMQAZgA2gCEAENAIgAiQBHACjAFKALcAZQA1QBsgDvAH4ARgAjgBV4C0ALSAYoA3AB1AD5AIvASIAmwBYoC2AF2gMPAZEAycoA1AAEABcAD4AIQAcgA_ACsAF8AMgAbQBHACRAFyAL4AYQAywBqADXAG0AOIAc4A6gB3ADwAIAAQcAhIBFQCbQE-AT8ApYBYgC6gGAAMIAYoA14BvADtgHkAP-Aj0BMQCbQFIAKYAVMArsBaAC6AF9AMCAYsUgfAALgAoACoAGQAOAAgABUADEAGgAPIAhgCIAEwAJ4AUgAqgBYAC4AGIAMwAcwBCACGgEQARIAowBSgCxAFuAMoAaIA1QBsgDvgH2AfoBFgCMAEcAJSAUMAq4BWwC5gF5ANoAbgA9ACLwEiAJsATsAocBTQCtgFigLYAXAAuQBdoDDQGHgMYAZEAyQBk4AAA.f_gAD_gAAAAA; _gcl_aw=GCL.1613471824.Cj0KCQiA962BBhCzARIsAIpWEL0e3aTFY8v7VUP4CZH6kyOUeLJqFVxbSZCVYkn_qNV0abAV3bomAtMaAqHQEALw_wcB; _lm_id=HUU4W4P38FGS25X7; _gid=GA1.2.1394619254.1613471833; _gcl_au=1.1.1558857812.1613471833; _fbp=fb.1.1613471833369.461617029; __gads=ID=b72ab920d933e8bf:T=1613471835:S=ALNI_MafbiTbXrZwvv5zDSShVP1lpSrlUg; OptanonConsent=isIABGlobal=false&datestamp=Tue+Feb+16+2021+11%3A47%3A42+GMT%2B0100+(Central+European+Standard+Time)&version=6.12.0&hosts=&consentId=6768f35d-a203-44ba-9479-3adfcab03b5b&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CSTACK42%3A1&geolocation=FR%3BIDF&AwaitingReconsent=false; _ga=GA1.1.1553445643.1613471833; __cf_bm=c85476545ac06cfc23f0a74950f09f5727902c65-1613475468-1800-AUe9vqwDwsb68ZPKbyJESUJV36qALMWV/RwIh4TnUdpJAS35C2hpgGBZK0KE+v/YFzEAKpXJduocBGJPpzGrJf14/HPkyhuzbOGdtDtZzWJO; _vinted_fr_session=...%3D%3D--78ac828f9c2316ba6a2d687571329deb29ccf264; _ga_ZJHK1N3D75=GS1.1.1613475474.2.1.1613475764.60
pragma: no-cache
referer: https://www.vinted.fr/vetements?catalog[]=1918&time=1613475699
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36
x-csrf-token: Tuz/8RjSnoQ9iYWMg0Ny4aoBcpfoNA3idgekPzag+pcc/a6O5cBFXoKqLdlwWUfgh5mT7vjQ4ScbcD0iwqOQ+g=="""

# %%
headers = {h[0]:h[1] for x in text.split('\n') if (h := x.split(': '))}
headers
# Out:
# {'accept': 'application/json, text/plain, */*',
#  'accept-encoding': 'gzip, deflate, br',
#  'accept-language': 'fr',
#  'cache-control': 'no-cache',
#  'cookie': '__cfduid=d69fa43e7997998c5457bc30c056fc2281613471817; anon_id=6197135a-6861-446c-b004-c8a831cf02f8; G_ENABLED_IDPS=google; OptanonAlertBoxClosed=2021-02-16T10:37:03.550Z; eupubconsent-v2=CPBtEMIPBtEMIAcABBENBNCsAP_AAH_AAChQGXNf_X9fb2vj-_5999t0eY1f9_63t-wzjgeNs-8NyZ_X_J4Xt2MyvB34pqYKmR4EunLBAQdlHGHcTQgAwIkVqTLsYk2MjzNKJ7JEilMbe2dYGH9vn8XT-ZKY70-s___7v3-_____7pAy4AAAgAICAEABQIAAgCAAAAAAIAAAAAAAAwMAggAACAGIAAAIggAAACABABAADAAAIAAAAAAAAACAAAIAAAAAAAAAAAAAAAAARAAAAALAgAAAAAABAAAAAABABAgAgAMCAgAYACMAICAQBOAAKABwAHgAXAA-AC0AHwASQAxAB_AEUAJEAXwAzQBtADiAHIAOcAdQA_wCBgEHAIuAT8AoYBhAEPgI9ASsAm0BYQC0AF0ALqAXaAvIBiADFgGQgMoCQSQAEAALgAoACoAGQAOAAeABAACIAFQANAAeQBDAEQAJgAT4AqgCsAFgALgAbwA5gB6AEIAIaARABEgCOAEsAJoAUoAtwBhgDIAGXANQA1QBsgDvAHsAPiAfYB-gEYAI0ARwAlIBSwCrgFzAL8AYoA1gBtADcAG8APQAfIBDYCLwEiAJiATKAmwBOwChwFIgLFAWwAuQBd4DAgGDAMJAYaAw8BkQDJAGThgBgACwALgBJADEANIAaoA4gDZAHUAUOAvoBkYaA4ACoAKwAXABDADIAGWANQAbIA_-AC0AHIAPwAggBdAC-AGQANAAfwBFACRAFmAL4AYQAywBmgDSAGqANoAcQA5ABzgDqAHcAQAAgcBBwEIAIiARcAm0BPgE_..._AB_gEYAI4ASkAoYBV4C0ALSAXMAvwBigDaAHUAPQAkEBIgCVAE2AKaAWKAtEBbAC4AFyALtAYeAxIBkQDJyQBoAAQADgALgAhAByAF8AMgAkQBcgC-AGWANQAbQA7gCEgFQALqAa8A3gB9gErAJtAUmAsoBfQDFiUCwABAACwAKAAZAA4ACIAGIAPAAiABMACqAFwAMQAZgA2gCEAENAIgAiQBHACjAFKALcAZQA1QBsgDvAH4ARgAjgBV4C0ALSAYoA3AB1AD5AIvASIAmwBYoC2AF2gMPAZEAycoA1AAEABcAD4AIQAcgA_ACsAF8AMgAbQBHACRAFyAL4AYQAywBqADXAG0AOIAc4A6gB3ADwAIAAQcAhIBFQCbQE-AT8ApYBYgC6gGAAMIAYoA14BvADtgHkAP-Aj0BMQCbQFIAKYAVMArsBaAC6AF9AMCAYsUgfAALgAoACoAGQAOAAgABUADEAGgAPIAhgCIAEwAJ4AUgAqgBYAC4AGIAMwAcwBCACGgEQARIAowBSgCxAFuAMoAaIA1QBsgDvgH2AfoBFgCMAEcAJSAUMAq4BWwC5gF5ANoAbgA9ACLwEiAJsATsAocBTQCtgFigLYAXAAuQBdoDDQGHgMYAZEAyQBk4AAA.f_gAD_gAAAAA; _gcl_aw=GCL.1613471824.Cj0KCQiA962BBhCzARIsAIpWEL0e3aTFY8v7VUP4CZH6kyOUeLJqFVxbSZCVYkn_qNV0abAV3bomAtMaAqHQEALw_wcB; _lm_id=HUU4W4P38FGS25X7; _gid=GA1.2.1394619254.1613471833; _gcl_au=1.1.1558857812.1613471833; _fbp=fb.1.1613471833369.461617029; __gads=ID=b72ab920d933e8bf:T=1613471835:S=ALNI_MafbiTbXrZwvv5zDSShVP1lpSrlUg; OptanonConsent=isIABGlobal=false&datestamp=Tue+Feb+16+2021+11%3A47%3A42+GMT%2B0100+(Central+European+Standard+Time)&version=6.12.0&hosts=&consentId=6768f35d-a203-44ba-9479-3adfcab03b5b&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CSTACK42%3A1&geolocation=FR%3BIDF&AwaitingReconsent=false; _ga=GA1.1.1553445643.1613471833; __cf_bm=c85476545ac06cfc23f0a74950f09f5727902c65-1613475468-1800-AUe9vqwDwsb68ZPKbyJESUJV36qALMWV/RwIh4TnUdpJAS35C2hpgGBZK0KE+v/YFzEAKpXJduocBGJPpzGrJf14/HPkyhuzbOGdtDtZzWJO; _vinted_fr_session=...%3D%3D--78ac828f9c2316ba6a2d687571329deb29ccf264; _ga_ZJHK1N3D75=GS1.1.1613475474.2.1.1613475764.60',
#  'pragma': 'no-cache',
#  'referer': 'https://www.vinted.fr/vetements?catalog[]=1918&time=1613475699',
#  'sec-fetch-dest': 'empty',
#  'sec-fetch-mode': 'cors',
#  'sec-fetch-site': 'same-origin',
#  'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
#  'x-csrf-token': 'Tuz/8RjSnoQ9iYWMg0Ny4aoBcpfoNA3idgekPzag+pcc/a6O5cBFXoKqLdlwWUfgh5mT7vjQ4ScbcD0iwqOQ+g=='}

# %%
response = requests.get(URL, headers=headers)
response
# Out:
# <Response [200]>

# %%
data = response.json()["items"]
data
# Out:
# [{'id': 907487278,
#   'title': 'Sottopentola',
#   'brand_id': 280391,
#   'size_id': None,
#   'status_id': 1,
#   'disposal_conditions': 4,
#   'user_id': 51227227,
#   'owner_id': None,
#   'country_id': 18,
#   'catalog_id': 1961,
#   'color1_id': 4,
#   'color2_id': None,
#   'package_size_id': 8,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 0,
#   'favourite_count': 0,
#   'view_count': 4,
#   'moderation_status': 0,
#   'last_push_up_at': '2021-02-16T12:40:17+01:00',
#   'description': 'sottopendola in stile nordico realizzato interamente a mano con manico in cuoio\n',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '',
#   'brand': 'Mano',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
#   'is_for_give_away': False,
#   'is_handicraft': False,
#   'is_draft': False,
#   'label': 'Mano',
#   'real_value_numeric': None,
#   'original_price_numeric': '25.0',
#   'currency': 'EUR',
#   'price_numeric': '25.0',
#   'created_at_ts': '2021-02-16T12:33:12+01:00',
#   'updated_at_ts': '2021-02-16T12:40:18+01:00',
#   'user_updated_at_ts': '2021-02-16T12:40:17+01:00',
#   'photos': [{'id': 3234133703,
#     'image_no': 1,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#232120',
#     'dominant_color_opaque': '#BDBCBC',
#     'url': 'https://images.vinted.net/thumbs/f800/02_0027f_dGLk2dTYNrPZzYT29ykeHHvU.jpeg?1613475193-50ce7038f18ddef634219c83346546f24374dda0',
#     'is_main': True,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_0027f_dGLk2dTYNrPZzYT29ykeHHvU.jpeg?1613475193-cdc89e9c48844e2c6b661fada7ca15c4ad456e09',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_0027f_dGLk2dTYNrPZzYT29ykeHHvU.jpeg?1613475193-b7f7029e8c93cb09d1fb83bc4c6f3f4f54dc36dc',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_0027f_dGLk2dTYNrPZzYT29ykeHHvU.jpeg?1613475193-98be2a4e6cb69082426aab7e97527ba3bd6a253c',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0027f_dGLk2dTYNrPZzYT29ykeHHvU.jpeg?1613475193-50ce7038f18ddef634219c83346546f24374dda0',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0027f_dGLk2dTYNrPZzYT29ykeHHvU.jpeg?1613475193-50ce7038f18ddef634219c83346546f24374dda0',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0027f_dGLk2dTYNrPZzYT29ykeHHvU.jpeg?1613475193-50ce7038f18ddef634219c83346546f24374dda0',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_0027f_dGLk2dTYNrPZzYT29ykeHHvU',
#      'timestamp': 1613475193,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_0027f_dGLk2dTYNrPZzYT29ykeHHvU.jpeg?1613475193-97f3fd45f4a2a01d32b6e6b4032871ced26ef969',
#     'extra': []},
#    {'id': 3234135197,
#     'image_no': 2,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#282828',
#     'dominant_color_opaque': '#BFBFBF',
#     'url': 'https://images.vinted.net/thumbs/f800/02_013e9_vXmBBJ5sAjxwknYCoHFQTFKc.jpeg?1613475193-84d750aa9ccc504dc1704430153c3dee8813100e',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_013e9_vXmBBJ5sAjxwknYCoHFQTFKc.jpeg?1613475193-5d8f7a0ff93a8a27bb9337600e8cf4d5a4d70869',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_013e9_vXmBBJ5sAjxwknYCoHFQTFKc.jpeg?1613475193-e4d019a373bb5f6df8eaab6a935831ca25ca58e6',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_013e9_vXmBBJ5sAjxwknYCoHFQTFKc.jpeg?1613475193-e026805e3f011ec78f429ad00f758e6e60508089',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_013e9_vXmBBJ5sAjxwknYCoHFQTFKc.jpeg?1613475193-84d750aa9ccc504dc1704430153c3dee8813100e',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_013e9_vXmBBJ5sAjxwknYCoHFQTFKc.jpeg?1613475193-84d750aa9ccc504dc1704430153c3dee8813100e',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_013e9_vXmBBJ5sAjxwknYCoHFQTFKc.jpeg?1613475193-84d750aa9ccc504dc1704430153c3dee8813100e',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_013e9_vXmBBJ5sAjxwknYCoHFQTFKc',
#      'timestamp': 1613475193,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_013e9_vXmBBJ5sAjxwknYCoHFQTFKc.jpeg?1613475193-e4b31a6594782aa748d9f11a7471690eda5d52b8',
#     'extra': []},
#    {'id': 3234172391,
#     'image_no': 3,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#443E39',
#     'dominant_color_opaque': '#C7C5C4',
#     'url': 'https://images.vinted.net/thumbs/f800/02_012aa_WJpXxapioZZnBS1vfHgoDasv.jpeg?1613475388-03604788178ddc481898fd2da98f26ba39d58011',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_012aa_WJpXxapioZZnBS1vfHgoDasv.jpeg?1613475388-2263ca9a2f9870527a1a391aea6c7071e5d22ff9',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_012aa_WJpXxapioZZnBS1vfHgoDasv.jpeg?1613475388-c624f41a62a0f88e4da4dc3f8a96db0fba0b1df5',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_012aa_WJpXxapioZZnBS1vfHgoDasv.jpeg?1613475388-49b4117714af2667dd8de5e034ff2746e06f53d6',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_012aa_WJpXxapioZZnBS1vfHgoDasv.jpeg?1613475388-03604788178ddc481898fd2da98f26ba39d58011',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_012aa_WJpXxapioZZnBS1vfHgoDasv.jpeg?1613475388-03604788178ddc481898fd2da98f26ba39d58011',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_012aa_WJpXxapioZZnBS1vfHgoDasv.jpeg?1613475388-03604788178ddc481898fd2da98f26ba39d58011',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_012aa_WJpXxapioZZnBS1vfHgoDasv',
#      'timestamp': 1613475388,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_012aa_WJpXxapioZZnBS1vfHgoDasv.jpeg?1613475388-b4de7b89501be2cb24d290d21f3e8115354b4727',
#     'extra': []}],
#   'push_up_interval': 604800,
#   'can_be_sold': True,
#   'can_feedback': False,
#   'path': '/maison/plateaux/907487278-sottopentola',
#   'possible_to_request_reservation': True,
#   'item_reservation_id': None,
#   'receiver_id': None,
#   'promoted_until': '2021-02-19T12:40:18+01:00',
#   'discount_price_numeric': None,
#   'badge': None,
#   'reservation_requests_from_users': [],
#   'material_id': 10,
#   'author': None,
#   'book_title': None,
#   'isbn': None,
#   'defect_ids': [],
#   'user': {'id': 51227227,
#    'anon_id': 'f60335ad-e063-4499-a7fc-90e1bcd07eba',
#    'login': 'karolina21630',
#    'real_name': None,
#    'email': None,
#    'birthday': None,
#    'gender': '',
#    'item_count': 17,
#    'msg_template_count': 1,
#    'given_item_count': 4,
#    'taken_item_count': 0,
#    'favourite_topic_count': 0,
#    'forum_msg_count': 0,
#    'forum_topic_count': 0,
#    'followers_count': 11,
#    'following_count': 0,
#    'following_brands_count': 0,
#    'positive_feedback_count': 0,
#    'neutral_feedback_count': 0,
#    'negative_feedback_count': 0,
#    'meeting_transaction_count': 0,
#    'account_status': 0,
#    'email_bounces': None,
#    'feedback_reputation': 0.0,
#    'account_ban_date': None,
#    'forum_ban_date': None,
#    'is_on_holiday': False,
#    'is_publish_photos_agreed': False,
#    'is_shadow_banned': False,
#    'is_identity': False,
#    'expose_location': True,
#    'third_party_tracking': True,
#    'default_address': None,
#    'created_at': '2021-01-25T17:23:35+01:00',
#    'last_loged_on_ts': '2021-02-16T12:48:21+01:00',
#    'city_id': 147971,
#    'city': 'Torino',
#    'country_id': 18,
#    'country_code': 'IT',
#    'country_iso_code': 'IT',
#    'country_title_local': 'Italia',
#    'country_title': 'Italia',
#    'contacts_permission': None,
#    'contacts': None,
#    'photo': None,
#    'path': '/member/51227227-karolina21630',
#    'is_god': False,
#    'is_tester': False,
#    'moderator': False,
#    'volunteer_moderator': False,
#    'hide_feedback': False,
#    'can_post_big_forum_photos': False,
#    'allow_direct_messaging': True,
#    'bundle_discount': None,
#    'donation_configuration': None,
#    'total_items_count': 21,
#    'about': '',
#    'verification': {'email': {'valid': True, 'available': True},
#     'facebook': {'valid': False,
#      'verified_at': None,
#      'available': True,
#      'friend_count': None},
#     'google': {'valid': False, 'verified_at': None, 'available': True},
#     'phone': {'valid': False, 'verified_at': None, 'available': True}},
#    'closet_promoted_until': None,
#    'avg_response_time': None,
#    'carrier_ids': [59, 9, 10],
#    'carriers_without_custom_ids': [59],
#    'updated_on': 1613475193,
#    'is_hated': False,
#    'hates_you': False,
#    'is_favourite': False,
#    'profile_url': 'https://www.vinted.fr/member/51227227-karolina21630',
#    'facebook_user_id': None,
#    'is_online': False,
#    'has_promoted_closet': False,
#    'can_view_profile': True,
#    'can_bundle': True,
#    'last_loged_on': "aujourd'hui 12:48",
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Carte bancaire',
#      'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#     {'id': 4,
#      'code': 'SOFORT',
#      'requires_credit_card': False,
#      'event_tracking_code': 'sofort',
#      'icon': 'sofort',
#      'enabled': True,
#      'translated_name': 'Sofort',
#      'note': ''},
#     {'id': 16,
#      'code': 'APPLE_PAY',
#      'requires_credit_card': False,
#      'event_tracking_code': 'apple_pay',
#      'icon': 'apple-pay',
#      'enabled': True,
#      'translated_name': 'Apple Pay',
#      'note': ''},
#     {'id': 10,
#      'code': 'MANGOPAY_PAYPAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'mangopay_paypal',
#      'icon': 'paypal',
#      'enabled': True,
#      'translated_name': 'PayPal',
#      'note': ''},
#     {'id': 9,
#      'code': 'IDEAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'ideal',
#      'icon': 'ideal',
#      'enabled': True,
#      'translated_name': 'iDeal',
#      'note': ''}],
#    'localization': 'manual'},
#   'price': '25,00 €',
#   'discount_price': '',
#   'real_value': '',
#   'can_edit': False,
#   'can_delete': False,
#   'can_request_reservation': False,
#   'can_cancel_reservation_request': False,
#   'can_reserve': False,
#   'can_transfer': False,
#   'instant_buy': True,
#   'can_close': False,
#   'can_buy': True,
#   'can_bundle': True,
#   'can_ask_seller': True,
#   'can_favourite': False,
#   'user_login': 'karolina21630',
#   'city_id': 147971,
#   'city': 'Torino',
#   'country': 'Italia',
#   'nearby': None,
#   'distance': None,
#   'promoted': True,
#   'is_favourite': False,
#   'is_mobile': False,
#   'bump_badge_visible': False,
#   'brand_dto': {'id': 280391,
#    'title': 'Mano',
#    'slug': 'mano',
#    'favourite_count': 138,
#    'pretty_favourite_count': '138',
#    'item_count': 44667,
#    'pretty_item_count': '44.7K',
#    'is_visible_in_listings': True,
#    'path': '/brand/mano',
#    'requires_authenticity_check': False,
#    'url': 'https://www.vinted.fr/brand/mano',
#    'is_favourite': False,
#    'is_hated': False},
#   'url': 'https://www.vinted.fr/maison/plateaux/907487278-sottopentola',
#   'accepted_pay_in_methods': [{'id': 1,
#     'code': 'CREDIT_CARD',
#     'requires_credit_card': True,
#     'event_tracking_code': 'cc',
#     'icon': 'credit-card',
#     'enabled': True,
#     'translated_name': 'Carte bancaire',
#     'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#    {'id': 10,
#     'code': 'MANGOPAY_PAYPAL',
#     'requires_credit_card': False,
#     'event_tracking_code': 'mangopay_paypal',
#     'icon': 'paypal',
#     'enabled': True,
#     'translated_name': 'PayPal',
#     'note': ''}],
#   'created_at': "aujourd'hui 12:33",
#   'color1': 'Beige ',
#   'color2': None,
#   'material': 'Bois',
#   'status': 'Neuf sans étiquette',
#   'secure_purchase': True,
#   'performance': None,
#   'stats_visible': True,
#   'can_push_up': False,
#   'size_guide_faq_entry_id': None,
#   'localization': 'manual'},
#  {'id': 900688413,
#   'title': 'Libro ',
#   'brand_id': 1,
#   'size_id': None,
#   'status_id': 2,
#   'disposal_conditions': 4,
#   'user_id': 52875067,
#   'owner_id': None,
#   'country_id': 7,
#   'catalog_id': 2029,
#   'color1_id': None,
#   'color2_id': None,
#   'package_size_id': 3,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 0,
#   'favourite_count': 5,
#   'view_count': 64,
#   'moderation_status': 0,
#   'last_push_up_at': '2021-02-15T12:38:55+01:00',
#   'description': 'Triología de algo tan sencillo como.\nSolo han sido leidos una vez y se encuentran en buenas condiciones.\nLas tapas estan un poco estropeadas por las esquinas de los costados pero casi no se aprecia, lo podeis ver en la última foto. ',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '',
#   'brand': '',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
#   'is_for_give_away': False,
#   'is_handicraft': False,
#   'is_draft': False,
#   'label': '',
#   'real_value_numeric': None,
#   'original_price_numeric': '25.0',
#   'currency': 'EUR',
#   'price_numeric': '20.0',
#   'created_at_ts': '2021-02-12T20:35:21+01:00',
#   'updated_at_ts': '2021-02-16T12:40:03+01:00',
#   'user_updated_at_ts': '2021-02-16T12:40:03+01:00',
#   'photos': [{'id': 3206815563,
#     'image_no': 1,
#     'width': 450,
#     'height': 800,
#     'dominant_color': '#8C8A84',
#     'dominant_color_opaque': '#DDDCDA',
#     'url': 'https://images.vinted.net/thumbs/f800/02_0053c_YG9HsUxvzPEBgspTdPGNh1Sb.jpeg?1613158521-813e25b50f70d5ffe9f719e90f4211d9256def75',
#     'is_main': True,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_0053c_YG9HsUxvzPEBgspTdPGNh1Sb.jpeg?1613158521-24bc5bb0af4297c322b449dd3df5c60aa4164494',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_0053c_YG9HsUxvzPEBgspTdPGNh1Sb.jpeg?1613158521-4da49cacf61078fb60df9a2d249f3c4c745282d9',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_0053c_YG9HsUxvzPEBgspTdPGNh1Sb.jpeg?1613158521-499b1e5579391f1c20cefb26dff60ae539b27a62',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0053c_YG9HsUxvzPEBgspTdPGNh1Sb.jpeg?1613158521-813e25b50f70d5ffe9f719e90f4211d9256def75',
#       'width': 240,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0053c_YG9HsUxvzPEBgspTdPGNh1Sb.jpeg?1613158521-813e25b50f70d5ffe9f719e90f4211d9256def75',
#       'width': 351,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0053c_YG9HsUxvzPEBgspTdPGNh1Sb.jpeg?1613158521-813e25b50f70d5ffe9f719e90f4211d9256def75',
#       'width': 204,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_0053c_YG9HsUxvzPEBgspTdPGNh1Sb',
#      'timestamp': 1613158521,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_0053c_YG9HsUxvzPEBgspTdPGNh1Sb.jpeg?1613158521-982b7be012e2fd5efaa00af5b7ca54b4dca5ef3f',
#     'extra': []},
#    {'id': 3206815685,
#     'image_no': 2,
#     'width': 450,
#     'height': 800,
#     'dominant_color': '#959194',
#     'dominant_color_opaque': '#DFDEDF',
#     'url': 'https://images.vinted.net/thumbs/f800/02_01af7_TkWhh2TStbDojpC9MjVRPPcD.jpeg?1613158521-b5796765cc047aa1f09bc15a7d30c4d8dff2eb74',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_01af7_TkWhh2TStbDojpC9MjVRPPcD.jpeg?1613158521-023f307b410313eae5a86ae4ffc9c395726c27ee',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_01af7_TkWhh2TStbDojpC9MjVRPPcD.jpeg?1613158521-a11ef53f3690653c7a7f30d9b22c51fc0dac6500',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_01af7_TkWhh2TStbDojpC9MjVRPPcD.jpeg?1613158521-c05b04a1736f42b3f183cc2197cbc8ec998b568a',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01af7_TkWhh2TStbDojpC9MjVRPPcD.jpeg?1613158521-b5796765cc047aa1f09bc15a7d30c4d8dff2eb74',
#       'width': 240,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01af7_TkWhh2TStbDojpC9MjVRPPcD.jpeg?1613158521-b5796765cc047aa1f09bc15a7d30c4d8dff2eb74',
#       'width': 351,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01af7_TkWhh2TStbDojpC9MjVRPPcD.jpeg?1613158521-b5796765cc047aa1f09bc15a7d30c4d8dff2eb74',
#       'width': 204,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_01af7_TkWhh2TStbDojpC9MjVRPPcD',
#      'timestamp': 1613158521,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_01af7_TkWhh2TStbDojpC9MjVRPPcD.jpeg?1613158521-cf4275cb2d751243398f17a83caf9a7a6eab5dc0',
#     'extra': []},
#    {'id': 3206815840,
#     'image_no': 3,
#     'width': 450,
#     'height': 800,
#     'dominant_color': '#B59A82',
#     'dominant_color_opaque': '#E9E1DA',
#     'url': 'https://images.vinted.net/thumbs/f800/02_00579_6tT92rHtJw3WDCWj3kMhw1bj.jpeg?1613158521-5abf6c7ac1d2558a840f3dbd2dfbbce3e2a8ff55',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_00579_6tT92rHtJw3WDCWj3kMhw1bj.jpeg?1613158521-82a9373d725ea56fd14f91d5578ade2d39ecc5ec',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_00579_6tT92rHtJw3WDCWj3kMhw1bj.jpeg?1613158521-daccf1fdd94431c27ee54bdd70a450fe12d6494b',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_00579_6tT92rHtJw3WDCWj3kMhw1bj.jpeg?1613158521-b7a579eee37156ce7e519c42886b5c9f0142feb3',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00579_6tT92rHtJw3WDCWj3kMhw1bj.jpeg?1613158521-5abf6c7ac1d2558a840f3dbd2dfbbce3e2a8ff55',
#       'width': 240,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00579_6tT92rHtJw3WDCWj3kMhw1bj.jpeg?1613158521-5abf6c7ac1d2558a840f3dbd2dfbbce3e2a8ff55',
#       'width': 351,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00579_6tT92rHtJw3WDCWj3kMhw1bj.jpeg?1613158521-5abf6c7ac1d2558a840f3dbd2dfbbce3e2a8ff55',
#       'width': 204,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_00579_6tT92rHtJw3WDCWj3kMhw1bj',
#      'timestamp': 1613158521,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_00579_6tT92rHtJw3WDCWj3kMhw1bj.jpeg?1613158521-6e0d24d0a8b8fdd5619ce50ef159fb14f97ef3bc',
#     'extra': []},
#    {'id': 3206815985,
#     'image_no': 4,
#     'width': 450,
#     'height': 800,
#     'dominant_color': '#958D8A',
#     'dominant_color_opaque': '#DFDDDC',
#     'url': 'https://images.vinted.net/thumbs/f800/02_022f4_gxArBJu3kWXmHmRn9mZgEcFN.jpeg?1613158521-ff4e43447ba394e0a6ab3c46167aa65fd006cc99',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_022f4_gxArBJu3kWXmHmRn9mZgEcFN.jpeg?1613158521-136c257b1a1ac1ecfb78e79b4d96d41558ddcdfe',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_022f4_gxArBJu3kWXmHmRn9mZgEcFN.jpeg?1613158521-62d1b0210dcb8d2cc32c82ff536fe108bcdbe5b0',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_022f4_gxArBJu3kWXmHmRn9mZgEcFN.jpeg?1613158521-6aab2c57d14ffc6e467b31d27143a4108a0523e5',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_022f4_gxArBJu3kWXmHmRn9mZgEcFN.jpeg?1613158521-ff4e43447ba394e0a6ab3c46167aa65fd006cc99',
#       'width': 240,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_022f4_gxArBJu3kWXmHmRn9mZgEcFN.jpeg?1613158521-ff4e43447ba394e0a6ab3c46167aa65fd006cc99',
#       'width': 351,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_022f4_gxArBJu3kWXmHmRn9mZgEcFN.jpeg?1613158521-ff4e43447ba394e0a6ab3c46167aa65fd006cc99',
#       'width': 204,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_022f4_gxArBJu3kWXmHmRn9mZgEcFN',
#      'timestamp': 1613158521,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_022f4_gxArBJu3kWXmHmRn9mZgEcFN.jpeg?1613158521-32d7d7eb4f075ba7c2e9934fa485b90daea0ce73',
#     'extra': []},
#    {'id': 3206860627,
#     'image_no': 5,
#     'width': 450,
#     'height': 800,
#     'dominant_color': '#A49E8E',
#     'dominant_color_opaque': '#E4E2DD',
#     'url': 'https://images.vinted.net/thumbs/f800/02_00094_jvjV8Tj9PKEKxzTGSijML31m.jpeg?1613158521-278bf36f208c378309229beb72dbc2964e704e3c',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_00094_jvjV8Tj9PKEKxzTGSijML31m.jpeg?1613158521-93648255e1f4d066f70a45084b459463866516d5',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_00094_jvjV8Tj9PKEKxzTGSijML31m.jpeg?1613158521-28f2263cea4465ff908e3c6be3badeb96e1a68ba',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_00094_jvjV8Tj9PKEKxzTGSijML31m.jpeg?1613158521-d65ea3de74a05b838988adc756818b5dfce6ae59',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00094_jvjV8Tj9PKEKxzTGSijML31m.jpeg?1613158521-278bf36f208c378309229beb72dbc2964e704e3c',
#       'width': 240,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00094_jvjV8Tj9PKEKxzTGSijML31m.jpeg?1613158521-278bf36f208c378309229beb72dbc2964e704e3c',
#       'width': 351,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00094_jvjV8Tj9PKEKxzTGSijML31m.jpeg?1613158521-278bf36f208c378309229beb72dbc2964e704e3c',
#       'width': 204,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_00094_jvjV8Tj9PKEKxzTGSijML31m',
#      'timestamp': 1613158521,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_00094_jvjV8Tj9PKEKxzTGSijML31m.jpeg?1613158521-ec6eb22354318d415e1488ad76cee1d8fe932c2e',
#     'extra': []}],
#   'push_up_interval': 604800,
#   'can_be_sold': True,
#   'can_feedback': False,
#   'path': '/maison/romance/900688413-libro',
#   'possible_to_request_reservation': True,
#   'item_reservation_id': None,
#   'receiver_id': None,
#   'promoted_until': '2021-02-22T12:38:55+01:00',
#   'discount_price_numeric': None,
#   'badge': None,
#   'reservation_requests_from_users': [],
#   'material_id': None,
#   'author': 'Blue Jeans',
#   'book_title': 'Algo Tan Sencillo Como Tuitear Te Quiero',
#   'isbn': '9788408194224',
#   'defect_ids': [],
#   'user': {'id': 52875067,
#    'anon_id': '3e9d6ec3-972a-4d0d-a92f-cdcd32511394',
#    'login': 'm.g_shop',
#    'real_name': None,
#    'email': None,
#    'birthday': None,
#    'gender': 'O',
#    'item_count': 6,
#    'msg_template_count': 0,
#    'given_item_count': 1,
#    'taken_item_count': 0,
#    'favourite_topic_count': 0,
#    'forum_msg_count': 0,
#    'forum_topic_count': 0,
#    'followers_count': 1,
#    'following_count': 0,
#    'following_brands_count': 0,
#    'positive_feedback_count': 0,
#    'neutral_feedback_count': 0,
#    'negative_feedback_count': 0,
#    'meeting_transaction_count': 0,
#    'account_status': 0,
#    'email_bounces': None,
#    'feedback_reputation': 0.0,
#    'account_ban_date': None,
#    'forum_ban_date': None,
#    'is_on_holiday': False,
#    'is_publish_photos_agreed': False,
#    'is_shadow_banned': False,
#    'is_identity': False,
#    'expose_location': True,
#    'third_party_tracking': True,
#    'created_at': '2021-02-12T18:49:21+01:00',
#    'last_loged_on_ts': '2021-02-16T11:52:44+01:00',
#    'city_id': None,
#    'city': '',
#    'country_id': 7,
#    'country_code': 'ES',
#    'country_iso_code': 'ES',
#    'country_title_local': 'España',
#    'country_title': 'España',
#    'contacts_permission': None,
#    'contacts': None,
#    'photo': None,
#    'path': '/member/52875067-mgshop',
#    'is_god': False,
#    'is_tester': False,
#    'moderator': False,
#    'volunteer_moderator': False,
#    'hide_feedback': False,
#    'can_post_big_forum_photos': False,
#    'allow_direct_messaging': True,
#    'bundle_discount': {'id': 8910098,
#     'user_id': 52875067,
#     'enabled': False,
#     'minimal_item_count': 2,
#     'fraction': '0.25',
#     'discounts': [{'minimal_item_count': 2, 'fraction': '0.25'},
#      {'minimal_item_count': 3, 'fraction': '0.3'},
#      {'minimal_item_count': 5, 'fraction': '0.5'}]},
#    'donation_configuration': None,
#    'total_items_count': 7,
#    'about': '',
#    'verification': {'email': {'valid': True, 'available': True},
#     'facebook': {'valid': False,
#      'verified_at': None,
#      'available': True,
#      'friend_count': None},
#     'google': {'valid': False, 'verified_at': None, 'available': True},
#     'phone': {'valid': False, 'verified_at': None, 'available': True}},
#    'closet_promoted_until': None,
#    'avg_response_time': None,
#    'carrier_ids': [11, 33, 34, 36, 44, 55, 4, 9, 10],
#    'carriers_without_custom_ids': [11, 33, 34, 36, 44, 55, 4],
#    'updated_on': 1613389056,
#    'is_hated': False,
#    'hates_you': False,
#    'is_favourite': False,
#    'profile_url': 'https://www.vinted.fr/member/52875067-mgshop',
#    'facebook_user_id': None,
#    'is_online': False,
#    'has_promoted_closet': False,
#    'can_view_profile': True,
#    'can_bundle': True,
#    'last_loged_on': "aujourd'hui 11:52",
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Carte bancaire',
#      'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#     {'id': 4,
#      'code': 'SOFORT',
#      'requires_credit_card': False,
#      'event_tracking_code': 'sofort',
#      'icon': 'sofort',
#      'enabled': True,
#      'translated_name': 'Sofort',
#      'note': ''},
#     {'id': 16,
#      'code': 'APPLE_PAY',
#      'requires_credit_card': False,
#      'event_tracking_code': 'apple_pay',
#      'icon': 'apple-pay',
#      'enabled': True,
#      'translated_name': 'Apple Pay',
#      'note': ''},
#     {'id': 10,
#      'code': 'MANGOPAY_PAYPAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'mangopay_paypal',
#      'icon': 'paypal',
#      'enabled': True,
#      'translated_name': 'PayPal',
#      'note': ''},
#     {'id': 9,
#      'code': 'IDEAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'ideal',
#      'icon': 'ideal',
#      'enabled': True,
#      'translated_name': 'iDeal',
#      'note': ''}],
#    'localization': 'manual',
#    'default_address': None},
#   'price': '20,00 €',
#   'discount_price': '',
#   'real_value': '',
#   'can_edit': False,
#   'can_delete': False,
#   'can_request_reservation': False,
#   'can_cancel_reservation_request': False,
#   'can_reserve': False,
#   'can_transfer': False,
#   'instant_buy': True,
#   'can_close': False,
#   'can_buy': True,
#   'can_bundle': True,
#   'can_ask_seller': True,
#   'can_favourite': False,
#   'user_login': 'm.g_shop',
#   'city_id': None,
#   'city': '',
#   'country': 'España',
#   'nearby': None,
#   'distance': None,
#   'promoted': True,
#   'is_favourite': False,
#   'is_mobile': False,
#   'bump_badge_visible': False,
#   'brand_dto': {'id': 1,
#    'title': '',
#    'slug': '',
#    'favourite_count': 13,
#    'pretty_favourite_count': '13',
#    'item_count': 74519921,
#    'pretty_item_count': '74.5M',
#    'is_visible_in_listings': False,
#    'path': '/brand/',
#    'requires_authenticity_check': False,
#    'url': 'https://www.vinted.fr/brand/',
#    'is_favourite': False,
#    'is_hated': False},
#   'url': 'https://www.vinted.fr/maison/romance/900688413-libro',
#   'accepted_pay_in_methods': [{'id': 1,
#     'code': 'CREDIT_CARD',
#     'requires_credit_card': True,
#     'event_tracking_code': 'cc',
#     'icon': 'credit-card',
#     'enabled': True,
#     'translated_name': 'Carte bancaire',
#     'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#    {'id': 10,
#     'code': 'MANGOPAY_PAYPAL',
#     'requires_credit_card': False,
#     'event_tracking_code': 'mangopay_paypal',
#     'icon': 'paypal',
#     'enabled': True,
#     'translated_name': 'PayPal',
#     'note': ''}],
#   'created_at': '12/02 20:35',
#   'color1': None,
#   'color2': None,
#   'material': None,
#   'status': 'Très bon état',
#   'secure_purchase': True,
#   'performance': None,
#   'stats_visible': True,
#   'can_push_up': False,
#   'size_guide_faq_entry_id': None,
#   'localization': 'manual'},
#  {'id': 901057979,
#   'title': 'Candelabro Normann Copenaghen Heima 4',
#   'brand_id': 4109681,
#   'size_id': None,
#   'status_id': 2,
#   'disposal_conditions': 4,
#   'user_id': 51903684,
#   'owner_id': None,
#   'country_id': 18,
#   'catalog_id': 1957,
#   'color1_id': 1,
#   'color2_id': None,
#   'package_size_id': 4,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 0,
#   'favourite_count': 5,
#   'view_count': 18,
#   'moderation_status': 0,
#   'last_push_up_at': '2021-02-15T12:39:03+01:00',
#   'description': 'Usato ma in condizioni impeccabili. ',
#   'package_size_standard': False,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '',
#   'brand': 'Normann Copenaghen',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
#   'is_for_give_away': False,
#   'is_handicraft': False,
#   'is_draft': False,
#   'label': 'Normann Copenaghen',
#   'real_value_numeric': None,
#   'original_price_numeric': '40.0',
#   'currency': 'EUR',
#   'price_numeric': '40.0',
#   'shipment_prices': {'domestic': '10.0', 'international': '13.0'},
#   'custom_shipment_price': '10.0',
#   'created_at_ts': '2021-02-13T09:45:25+01:00',
#   'updated_at_ts': '2021-02-16T12:40:03+01:00',
#   'user_updated_at_ts': '2021-02-16T12:40:03+01:00',
#   'photos': [{'id': 3208387160,
#     'image_no': 1,
#     'width': 600,
#     'height': 800,
#     'dominant_color': '#4E402D',
#     'dominant_color_opaque': '#CAC6C0',
#     'url': 'https://images.vinted.net/thumbs/f800/02_01dd5_MbQsr9s8zdKacq2sQ7QcUFrz.jpeg?1613205925-d688424b32e127ad27bdb11fb3d410c458da5908',
#     'is_main': True,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_01dd5_MbQsr9s8zdKacq2sQ7QcUFrz.jpeg?1613205925-1b48498ee86bf5079b0ccd58f7be101e6b95c6d0',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_01dd5_MbQsr9s8zdKacq2sQ7QcUFrz.jpeg?1613205925-481c3fd9792cb725ddf3a987089bf55b90129654',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_01dd5_MbQsr9s8zdKacq2sQ7QcUFrz.jpeg?1613205925-5b7e42af1940b23d649c608414b3029ae033a45a',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01dd5_MbQsr9s8zdKacq2sQ7QcUFrz.jpeg?1613205925-d688424b32e127ad27bdb11fb3d410c458da5908',
#       'width': 321,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01dd5_MbQsr9s8zdKacq2sQ7QcUFrz.jpeg?1613205925-d688424b32e127ad27bdb11fb3d410c458da5908',
#       'width': 468,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01dd5_MbQsr9s8zdKacq2sQ7QcUFrz.jpeg?1613205925-d688424b32e127ad27bdb11fb3d410c458da5908',
#       'width': 273,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_01dd5_MbQsr9s8zdKacq2sQ7QcUFrz',
#      'timestamp': 1613205925,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_01dd5_MbQsr9s8zdKacq2sQ7QcUFrz.jpeg?1613205925-c0e9db1d9d764f85a8c7442ee6d70ff37968dac4',
#     'extra': []}],
#   'push_up_interval': 604800,
#   'can_be_sold': True,
#   'can_feedback': False,
#   'path': '/maison/bougeoirs/901057979-candelabro-normann-copenaghen-heima-4',
#   'possible_to_request_reservation': True,
#   'item_reservation_id': None,
#   'receiver_id': None,
#   'promoted_until': '2021-02-22T12:39:03+01:00',
#   'discount_price_numeric': None,
#   'badge': None,
#   'reservation_requests_from_users': [],
#   'material_id': 6,
#   'author': None,
#   'book_title': None,
#   'isbn': None,
#   'defect_ids': [],
#   'user': {'id': 51903684,
#    'anon_id': '17fcac9b-2683-4bbe-b514-0ad80e9bc8e6',
#    'login': 'minasot',
#    'real_name': None,
#    'email': None,
#    'birthday': None,
#    'gender': '',
#    'item_count': 1,
#    'msg_template_count': 0,
#    'given_item_count': 1,
#    'taken_item_count': 4,
#    'favourite_topic_count': 0,
#    'forum_msg_count': 0,
#    'forum_topic_count': 0,
#    'followers_count': 1,
#    'following_count': 2,
#    'following_brands_count': 0,
#    'positive_feedback_count': 1,
#    'neutral_feedback_count': 0,
#    'negative_feedback_count': 0,
#    'meeting_transaction_count': 0,
#    'account_status': 0,
#    'email_bounces': None,
#    'feedback_reputation': 1.0,
#    'account_ban_date': None,
#    'forum_ban_date': None,
#    'is_on_holiday': False,
#    'is_publish_photos_agreed': False,
#    'is_shadow_banned': False,
#    'is_identity': False,
#    'expose_location': True,
#    'third_party_tracking': True,
#    'default_address': None,
#    'created_at': '2021-02-01T13:55:02+01:00',
#    'last_loged_on_ts': '2021-02-16T10:33:27+01:00',
#    'city_id': 183557,
#    'city': 'Oschiri',
#    'country_id': 18,
#    'country_code': 'IT',
#    'country_iso_code': 'IT',
#    'country_title_local': 'Italia',
#    'country_title': 'Italia',
#    'contacts_permission': None,
#    'contacts': None,
#    'photo': {'id': 47744427,
#     'width': 794,
#     'height': 800,
#     'temp_uuid': None,
#     'url': 'https://images.vinted.net/thumbs/f800/02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ.jpeg?1612184103-1769e3289d3a6625a13864873ba9bac76747b6ff',
#     'dominant_color': '#31abc2',
#     'dominant_color_opaque': '#C1E6ED',
#     'thumbnails': [{'type': 'thumb310',
#       'url': 'https://images.vinted.net/thumbs/310x310/02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ.jpeg?1612184103-6df01633e7a5b5f40cf1755355751a791a0383b8',
#       'width': 310,
#       'height': 310,
#       'original_size': None},
#      {'type': 'thumb150',
#       'url': 'https://images.vinted.net/thumbs/150x150/02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ.jpeg?1612184103-ae3bb1671f71e1482b7c2ad8768b5a6ee8fceb12',
#       'width': 150,
#       'height': 150,
#       'original_size': None},
#      {'type': 'thumb100',
#       'url': 'https://images.vinted.net/thumbs/100x100/02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ.jpeg?1612184103-5b8fd69d34d9026069222708477e22605cdc0294',
#       'width': 100,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb50',
#       'url': 'https://images.vinted.net/thumbs/50x50/02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ.jpeg?1612184103-7dcc3356b45f6819498bde4f639c31681eac104f',
#       'width': 50,
#       'height': 50,
#       'original_size': None},
#      {'type': 'thumb20',
#       'url': 'https://images.vinted.net/thumbs/20x20/02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ.jpeg?1612184103-31543e7236157c1ba19e9adf84c9c0ac18b69ab1',
#       'width': 20,
#       'height': 20,
#       'original_size': None}],
#     'is_suspicious': False,
#     'orientation': None,
#     'high_resolution': {'id': '02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ',
#      'timestamp': 1612184103,
#      'orientation': None},
#     'full_size_url': 'https://images.vinted.net/thumbs/02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ.jpeg?1612184103-624031af2a2e6593485a913d02262695f2f5973b',
#     'extra': []},
#    'path': '/member/51903684-minasot',
#    'is_god': False,
#    'is_tester': False,
#    'moderator': False,
#    'volunteer_moderator': False,
#    'hide_feedback': False,
#    'can_post_big_forum_photos': False,
#    'allow_direct_messaging': True,
#    'bundle_discount': None,
#    'donation_configuration': None,
#    'total_items_count': 2,
#    'about': '',
#    'verification': {'email': {'valid': True, 'available': True},
#     'facebook': {'valid': True,
#      'verified_at': '2021-02-01T13:54:37+01:00',
#      'available': True,
#      'friend_count': None},
#     'google': {'valid': False, 'verified_at': None, 'available': True},
#     'phone': {'valid': True,
#      'verified_at': '2021-02-12T11:20:00+01:00',
#      'available': True}},
#    'closet_promoted_until': None,
#    'avg_response_time': None,
#    'carrier_ids': [59, 9, 10],
#    'carriers_without_custom_ids': [59],
#    'updated_on': 1613158035,
#    'is_hated': False,
#    'hates_you': False,
#    'is_favourite': False,
#    'profile_url': 'https://www.vinted.fr/member/51903684-minasot',
#    'facebook_user_id': None,
#    'is_online': False,
#    'has_promoted_closet': False,
#    'can_view_profile': True,
#    'can_bundle': True,
#    'last_loged_on': "aujourd'hui 10:33",
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Carte bancaire',
#      'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#     {'id': 4,
#      'code': 'SOFORT',
#      'requires_credit_card': False,
#      'event_tracking_code': 'sofort',
#      'icon': 'sofort',
#      'enabled': True,
#      'translated_name': 'Sofort',
#      'note': ''},
#     {'id': 16,
#      'code': 'APPLE_PAY',
#      'requires_credit_card': False,
#      'event_tracking_code': 'apple_pay',
#      'icon': 'apple-pay',
#      'enabled': True,
#      'translated_name': 'Apple Pay',
#      'note': ''},
#     {'id': 10,
#      'code': 'MANGOPAY_PAYPAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'mangopay_paypal',
#      'icon': 'paypal',
#      'enabled': True,
#      'translated_name': 'PayPal',
#      'note': ''},
#     {'id': 9,
#      'code': 'IDEAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'ideal',
#      'icon': 'ideal',
#      'enabled': True,
#      'translated_name': 'iDeal',
#      'note': ''}],
#    'localization': 'manual'},
#   'price': '40,00 €',
#   'discount_price': '',
#   'real_value': '',
#   'can_edit': False,
#   'can_delete': False,
#   'can_request_reservation': False,
#   'can_cancel_reservation_request': False,
#   'can_reserve': False,
#   'can_transfer': False,
#   'instant_buy': True,
#   'can_close': False,
#   'can_buy': True,
#   'can_bundle': True,
#   'can_ask_seller': True,
#   'can_favourite': False,
#   'user_login': 'minasot',
#   'city_id': 183557,
#   'city': 'Oschiri',
#   'country': 'Italia',
#   'nearby': None,
#   'distance': None,
#   'promoted': True,
#   'is_favourite': False,
#   'is_mobile': False,
#   'bump_badge_visible': False,
#   'brand_dto': {'id': 4109681,
#    'title': 'Normann Copenaghen',
#    'slug': 'normann-copenaghen',
#    'favourite_count': 9,
#    'pretty_favourite_count': '11',
#    'item_count': 2,
#    'pretty_item_count': '2',
#    'is_visible_in_listings': False,
#    'path': '/brand/normann-copenaghen',
#    'requires_authenticity_check': False,
#    'url': 'https://www.vinted.fr/brand/normann-copenaghen',
#    'is_favourite': False,
#    'is_hated': False},
#   'url': 'https://www.vinted.fr/maison/bougeoirs/901057979-candelabro-normann-copenaghen-heima-4',
#   'accepted_pay_in_methods': [{'id': 1,
#     'code': 'CREDIT_CARD',
#     'requires_credit_card': True,
#     'event_tracking_code': 'cc',
#     'icon': 'credit-card',
#     'enabled': True,
#     'translated_name': 'Carte bancaire',
#     'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."}],
#   'created_at': '13/02 09:45',
#   'color1': 'Noir',
#   'color2': None,
#   'material': 'Métal',
#   'status': 'Très bon état',
#   'secure_purchase': True,
#   'performance': None,
#   'stats_visible': True,
#   'can_push_up': False,
#   'size_guide_faq_entry_id': None,
#   'localization': 'manual'},
#  {'id': 903185522,
#   'title': 'Le monde merveilleux des papillons tropicaux, magnifiques planches, rare à la vente 1950',
#   'brand_id': 1,
#   'size_id': None,
#   'status_id': 2,
#   'disposal_conditions': 4,
#   'user_id': 31582421,
#   'owner_id': None,
#   'country_id': 16,
#   'catalog_id': 2041,
#   'color1_id': None,
#   'color2_id': None,
#   'package_size_id': 1,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 0,
#   'favourite_count': 1,
#   'view_count': 0,
#   'moderation_status': 0,
#   'last_push_up_at': '2021-02-15T12:33:07+01:00',
#   'description': 'Le monde merveilleux des papillons tropicaux\nHANDSCHIN Eduard, ed. Silva. 1950, Cartonnage avec titre doré. Abondante illustration couleurs.\nVoir riche table des matières en 2 photos.\nlivre en très bon état car était couvert (juste marque de scotch voir photo)\n',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '',
#   'brand': '',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
#   'is_for_give_away': False,
#   'is_handicraft': False,
#   'is_draft': False,
#   'label': '',
#   'real_value_numeric': None,
#   'original_price_numeric': '48.0',
#   'currency': 'EUR',
#   'price_numeric': '48.0',
#   'created_at_ts': '2021-02-14T11:19:42+01:00',
#   'updated_at_ts': '2021-02-16T12:40:03+01:00',
#   'user_updated_at_ts': '2021-02-16T12:40:03+01:00',
#   'photos': [{'id': 3217137850,
#     'image_no': 1,
#     'width': 584,
#     'height': 800,
#     'dominant_color': '#68849A',
#     'dominant_color_opaque': '#D2DAE1',
#     'url': 'https://images.vinted.net/thumbs/f800/02_0012a_yN4C3WMuFitbToTbMaJR9W3c.jpeg?1613298401-ca43e70fa79e0cb3d25e59307875c68c21687f3d',
#     'is_main': True,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_0012a_yN4C3WMuFitbToTbMaJR9W3c.jpeg?1613298401-4658d4d2eb64464bd173db5aa80c559ccae38e82',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_0012a_yN4C3WMuFitbToTbMaJR9W3c.jpeg?1613298401-7f024824f5f3b1e61689fa466f87c4eb159cab5c',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_0012a_yN4C3WMuFitbToTbMaJR9W3c.jpeg?1613298401-546c1a38d28902a3595fe73f31785e4cb4543da4',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0012a_yN4C3WMuFitbToTbMaJR9W3c.jpeg?1613298401-ca43e70fa79e0cb3d25e59307875c68c21687f3d',
#       'width': 312,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0012a_yN4C3WMuFitbToTbMaJR9W3c.jpeg?1613298401-ca43e70fa79e0cb3d25e59307875c68c21687f3d',
#       'width': 455,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0012a_yN4C3WMuFitbToTbMaJR9W3c.jpeg?1613298401-ca43e70fa79e0cb3d25e59307875c68c21687f3d',
#       'width': 265,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_0012a_yN4C3WMuFitbToTbMaJR9W3c',
#      'timestamp': 1613298401,
#      'orientation': 0},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_0012a_yN4C3WMuFitbToTbMaJR9W3c.jpeg?1613298401-eed40d32ef1718f803390cfcf36daba030b83d9e',
#     'extra': []},
#    {'id': 3216971440,
#     'image_no': 2,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#7E8083',
#     'dominant_color_opaque': '#D8D9DA',
#     'url': 'https://images.vinted.net/thumbs/f800/02_026c1_nRuVxwsMZZieH4PJ5KBi45mv.jpeg?1613298401-07446492176b1f347a1beaba61ef904391e91eda',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
# ...
#   'item_reservation_id': None,
#   'receiver_id': None,
#   'promoted_until': '2021-02-20T12:30:00+01:00',
#   'discount_price_numeric': None,
#   'badge': None,
#   'reservation_requests_from_users': [],
#   'material_id': 1,
#   'author': None,
#   'book_title': None,
#   'isbn': None,
#   'defect_ids': [],
#   'user': {'id': 52540480,
#    'anon_id': '6d0ecb19-d568-4d69-b0e2-793f9d97d614',
#    'login': 'mj-2512',
#    'real_name': None,
#    'email': None,
#    'birthday': None,
#    'gender': '',
#    'item_count': 11,
#    'msg_template_count': 0,
#    'given_item_count': 1,
#    'taken_item_count': 0,
#    'favourite_topic_count': 0,
#    'forum_msg_count': 0,
#    'forum_topic_count': 0,
#    'followers_count': 0,
#    'following_count': 0,
#    'following_brands_count': 0,
#    'positive_feedback_count': 1,
#    'neutral_feedback_count': 0,
#    'negative_feedback_count': 0,
#    'meeting_transaction_count': 0,
#    'account_status': 0,
#    'email_bounces': None,
#    'feedback_reputation': 1.0,
#    'account_ban_date': None,
#    'forum_ban_date': None,
#    'is_on_holiday': False,
#    'is_publish_photos_agreed': False,
#    'is_shadow_banned': False,
#    'is_identity': False,
#    'expose_location': True,
#    'third_party_tracking': True,
#    'default_address': None,
#    'created_at': '2021-02-08T15:16:23+01:00',
#    'last_loged_on_ts': '2021-02-16T12:34:53+01:00',
#    'city_id': 57384,
#    'city': 'Flavin',
#    'country_id': 16,
#    'country_code': 'FR',
#    'country_iso_code': 'FR',
#    'country_title_local': 'France',
#    'country_title': 'France',
#    'contacts_permission': None,
#    'contacts': None,
#    'photo': None,
#    'path': '/member/52540480-mj-2512',
#    'is_god': False,
#    'is_tester': False,
#    'moderator': False,
#    'volunteer_moderator': False,
#    'hide_feedback': False,
#    'can_post_big_forum_photos': False,
#    'allow_direct_messaging': True,
#    'bundle_discount': {'id': 8919363,
#     'user_id': 52540480,
#     'enabled': True,
#     'minimal_item_count': 2,
#     'fraction': '0.05',
#     'discounts': [{'minimal_item_count': 2, 'fraction': '0.05'},
#      {'minimal_item_count': 3, 'fraction': '0.1'},
#      {'minimal_item_count': 5, 'fraction': '0.2'}]},
#    'donation_configuration': None,
#    'total_items_count': 12,
#    'about': '',
#    'verification': {'email': {'valid': True, 'available': True},
#     'facebook': {'valid': False,
#      'verified_at': None,
#      'available': True,
#      'friend_count': None},
#     'google': {'valid': False, 'verified_at': None, 'available': True},
#     'phone': {'valid': False, 'verified_at': None, 'available': True}},
#    'closet_promoted_until': None,
#    'avg_response_time': None,
#    'carrier_ids': [20, 27, 50, 59, 4, 3, 9, 10],
#    'carriers_without_custom_ids': [20, 27, 50, 59, 4, 3],
#    'updated_on': 1613417966,
#    'is_hated': False,
#    'hates_you': False,
#    'is_favourite': False,
#    'profile_url': 'https://www.vinted.fr/member/52540480-mj-2512',
#    'facebook_user_id': None,
#    'is_online': False,
#    'has_promoted_closet': False,
#    'can_view_profile': True,
#    'can_bundle': True,
#    'last_loged_on': "aujourd'hui 12:34",
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Carte bancaire',
#      'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#     {'id': 4,
#      'code': 'SOFORT',
#      'requires_credit_card': False,
#      'event_tracking_code': 'sofort',
#      'icon': 'sofort',
#      'enabled': True,
#      'translated_name': 'Sofort',
#      'note': ''},
#     {'id': 16,
#      'code': 'APPLE_PAY',
#      'requires_credit_card': False,
#      'event_tracking_code': 'apple_pay',
#      'icon': 'apple-pay',
#      'enabled': True,
#      'translated_name': 'Apple Pay',
#      'note': ''},
#     {'id': 10,
#      'code': 'MANGOPAY_PAYPAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'mangopay_paypal',
#      'icon': 'paypal',
#      'enabled': True,
#      'translated_name': 'PayPal',
#      'note': ''},
#     {'id': 9,
#      'code': 'IDEAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'ideal',
#      'icon': 'ideal',
#      'enabled': True,
#      'translated_name': 'iDeal',
#      'note': ''}],
#    'localization': 'manual'},
#   'price': '25,00 €',
#   'discount_price': '',
#   'real_value': '',
#   'can_edit': False,
#   'can_delete': False,
#   'can_request_reservation': False,
#   'can_cancel_reservation_request': False,
#   'can_reserve': False,
#   'can_transfer': False,
#   'instant_buy': True,
#   'can_close': False,
#   'can_buy': True,
#   'can_bundle': True,
#   'can_ask_seller': True,
#   'can_favourite': False,
#   'user_login': 'mj-2512',
#   'city_id': 57384,
#   'city': 'Flavin',
#   'country': 'France',
#   'nearby': None,
#   'distance': None,
#   'promoted': True,
#   'is_favourite': False,
#   'is_mobile': False,
#   'bump_badge_visible': False,
#   'brand_dto': {'id': 669490,
#    'title': 'côté nuit',
#    'slug': 'cote-nuit',
#    'favourite_count': 10,
#    'pretty_favourite_count': '10',
#    'item_count': 92,
#    'pretty_item_count': '92',
#    'is_visible_in_listings': False,
#    'path': '/brand/cote-nuit',
#    'requires_authenticity_check': False,
#    'url': 'https://www.vinted.fr/brand/cote-nuit',
#    'is_favourite': False,
#    'is_hated': False},
#   'url': 'https://www.vinted.fr/maison/housses-de-couette/901385747-housse-de-couette',
#   'accepted_pay_in_methods': [{'id': 1,
#     'code': 'CREDIT_CARD',
#     'requires_credit_card': True,
#     'event_tracking_code': 'cc',
#     'icon': 'credit-card',
#     'enabled': True,
#     'translated_name': 'Carte bancaire',
#     'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#    {'id': 10,
#     'code': 'MANGOPAY_PAYPAL',
#     'requires_credit_card': False,
#     'event_tracking_code': 'mangopay_paypal',
#     'icon': 'paypal',
#     'enabled': True,
#     'translated_name': 'PayPal',
#     'note': ''}],
#   'created_at': '13/02 12:20',
#   'color1': 'Vert',
#   'color2': 'Rose',
#   'material': 'Coton',
#   'status': 'Neuf avec étiquette',
#   'secure_purchase': True,
#   'performance': None,
#   'stats_visible': True,
#   'can_push_up': False,
#   'size_guide_faq_entry_id': None,
#   'localization': 'manual'},
#  {'id': 901378546,
#   'title': 'Meuble ',
#   'brand_id': 184302,
#   'size_id': None,
#   'status_id': 3,
#   'disposal_conditions': 4,
#   'user_id': 52420032,
#   'owner_id': None,
#   'country_id': 16,
#   'catalog_id': 1941,
#   'color1_id': 12,
#   'color2_id': None,
#   'package_size_id': 3,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 5,
#   'favourite_count': 19,
#   'view_count': 606,
#   'moderation_status': 0,
#   'last_push_up_at': '2021-02-13T12:29:45+01:00',
#   'description': 'En état propre ',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '',
#   'brand': 'Ikea',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
#   'is_for_give_away': False,
#   'is_handicraft': False,
#   'is_draft': False,
#   'label': 'Ikea',
#   'real_value_numeric': None,
#   'original_price_numeric': '50.0',
#   'currency': 'EUR',
#   'price_numeric': '50.0',
#   'created_at_ts': '2021-02-13T12:17:09+01:00',
#   'updated_at_ts': '2021-02-16T12:30:02+01:00',
#   'user_updated_at_ts': '2021-02-16T12:30:02+01:00',
#   'photos': [{'id': 3209695870,
#     'image_no': 1,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#C49EAA',
#     'dominant_color_opaque': '#EDE2E6',
#     'url': 'https://images.vinted.net/thumbs/f800/02_01010_2GK7i1CLaehjv7FFUAgtUngZ.jpeg?1613215029-a38b9b3e322da4a36403184edf907b54ac5a320b',
#     'is_main': True,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_01010_2GK7i1CLaehjv7FFUAgtUngZ.jpeg?1613215029-d0292a7ddbd6b594636c810b0a47ce3c51d3f36d',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_01010_2GK7i1CLaehjv7FFUAgtUngZ.jpeg?1613215029-0b28d2b4fbc7a2f8d6ae8b0fd160b91f7fcf52ab',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_01010_2GK7i1CLaehjv7FFUAgtUngZ.jpeg?1613215029-0eca8cea9cbf785b28693ab487c56f94bf7c709a',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01010_2GK7i1CLaehjv7FFUAgtUngZ.jpeg?1613215029-a38b9b3e322da4a36403184edf907b54ac5a320b',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01010_2GK7i1CLaehjv7FFUAgtUngZ.jpeg?1613215029-a38b9b3e322da4a36403184edf907b54ac5a320b',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01010_2GK7i1CLaehjv7FFUAgtUngZ.jpeg?1613215029-a38b9b3e322da4a36403184edf907b54ac5a320b',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_01010_2GK7i1CLaehjv7FFUAgtUngZ',
#      'timestamp': 1613215029,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_01010_2GK7i1CLaehjv7FFUAgtUngZ.jpeg?1613215029-5f2a3e76029e9bd162c0b9087992a6ad0f0cd6b4',
#     'extra': []}],
#   'push_up_interval': 604800,
#   'can_be_sold': True,
#   'can_feedback': False,
#   'path': '/maison/etageres-murales/901378546-meuble',
#   'possible_to_request_reservation': True,
#   'item_reservation_id': None,
#   'receiver_id': None,
#   'promoted_until': '2021-02-20T12:29:45+01:00',
#   'discount_price_numeric': None,
#   'badge': None,
#   'reservation_requests_from_users': [],
#   'material_id': 23,
#   'author': None,
#   'book_title': None,
#   'isbn': None,
#   'defect_ids': [],
#   'user': {'id': 52420032,
#    'anon_id': '9fc4bdad-d944-40b6-8e29-125922eebe7e',
#    'login': 'severinepartigianoni',
#    'real_name': None,
#    'email': None,
#    'birthday': None,
#    'gender': '',
#    'item_count': 6,
#    'msg_template_count': 0,
#    'given_item_count': 0,
#    'taken_item_count': 0,
#    'favourite_topic_count': 0,
#    'forum_msg_count': 0,
#    'forum_topic_count': 0,
#    'followers_count': 0,
#    'following_count': 0,
#    'following_brands_count': 0,
#    'positive_feedback_count': 0,
#    'neutral_feedback_count': 0,
#    'negative_feedback_count': 0,
#    'meeting_transaction_count': 0,
#    'account_status': 0,
#    'email_bounces': None,
#    'feedback_reputation': 0.0,
#    'account_ban_date': None,
#    'forum_ban_date': None,
#    'is_on_holiday': False,
#    'is_publish_photos_agreed': False,
#    'is_shadow_banned': False,
#    'is_identity': False,
#    'expose_location': True,
#    'third_party_tracking': True,
#    'created_at': '2021-02-07T12:35:46+01:00',
#    'last_loged_on_ts': '2021-02-16T06:02:08+01:00',
#    'city_id': 14585,
#    'city': 'Paris',
#    'country_id': 16,
#    'country_code': 'FR',
#    'country_iso_code': 'FR',
#    'country_title_local': 'France',
#    'country_title': 'France',
#    'contacts_permission': None,
#    'contacts': None,
#    'photo': None,
#    'path': '/member/52420032-severinepartigianoni',
#    'is_god': False,
#    'is_tester': False,
#    'moderator': False,
#    'volunteer_moderator': False,
#    'hide_feedback': False,
#    'can_post_big_forum_photos': False,
#    'allow_direct_messaging': True,
#    'bundle_discount': None,
#    'donation_configuration': None,
#    'total_items_count': 6,
#    'about': '',
#    'verification': {'email': {'valid': True, 'available': True},
#     'facebook': {'valid': False,
#      'verified_at': None,
#      'available': True,
#      'friend_count': None},
#     'google': {'valid': False, 'verified_at': None, 'available': True},
#     'phone': {'valid': True,
#      'verified_at': '2021-02-07T12:36:43+01:00',
#      'available': True}},
#    'closet_promoted_until': None,
#    'avg_response_time': None,
#    'carrier_ids': [20, 27, 50, 59, 4, 3, 9, 10],
#    'carriers_without_custom_ids': [20, 27, 50, 59, 4, 3],
#    'updated_on': 1613217868,
#    'is_hated': False,
#    'hates_you': False,
#    'is_favourite': False,
#    'profile_url': 'https://www.vinted.fr/member/52420032-severinepartigianoni',
#    'facebook_user_id': None,
#    'is_online': False,
#    'has_promoted_closet': False,
#    'can_view_profile': True,
#    'can_bundle': True,
#    'last_loged_on': "aujourd'hui 06:02",
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Carte bancaire',
#      'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#     {'id': 4,
#      'code': 'SOFORT',
#      'requires_credit_card': False,
#      'event_tracking_code': 'sofort',
#      'icon': 'sofort',
#      'enabled': True,
#      'translated_name': 'Sofort',
#      'note': ''},
#     {'id': 16,
#      'code': 'APPLE_PAY',
#      'requires_credit_card': False,
#      'event_tracking_code': 'apple_pay',
#      'icon': 'apple-pay',
#      'enabled': True,
#      'translated_name': 'Apple Pay',
#      'note': ''},
#     {'id': 10,
#      'code': 'MANGOPAY_PAYPAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'mangopay_paypal',
#      'icon': 'paypal',
#      'enabled': True,
#      'translated_name': 'PayPal',
#      'note': ''},
#     {'id': 9,
#      'code': 'IDEAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'ideal',
#      'icon': 'ideal',
#      'enabled': True,
#      'translated_name': 'iDeal',
#      'note': ''}],
#    'localization': 'manual',
#    'default_address': None},
#   'price': '50,00 €',
#   'discount_price': '',
#   'real_value': '',
#   'can_edit': False,
#   'can_delete': False,
#   'can_request_reservation': False,
#   'can_cancel_reservation_request': False,
#   'can_reserve': False,
#   'can_transfer': False,
#   'instant_buy': True,
#   'can_close': False,
#   'can_buy': True,
#   'can_bundle': True,
#   'can_ask_seller': True,
#   'can_favourite': False,
#   'user_login': 'severinepartigianoni',
#   'city_id': 14585,
#   'city': 'Paris',
#   'country': 'France',
#   'nearby': None,
#   'distance': None,
#   'promoted': True,
#   'is_favourite': False,
#   'is_mobile': False,
#   'bump_badge_visible': False,
#   'brand_dto': {'id': 184302,
#    'title': 'Ikea',
#    'slug': 'ikea',
#    'favourite_count': 21199,
#    'pretty_favourite_count': '21.2K',
#    'item_count': 252504,
#    'pretty_item_count': '252.5K',
#    'is_visible_in_listings': True,
#    'path': '/brand/ikea',
#    'requires_authenticity_check': False,
#    'url': 'https://www.vinted.fr/brand/ikea',
#    'is_favourite': False,
#    'is_hated': False},
#   'url': 'https://www.vinted.fr/maison/etageres-murales/901378546-meuble',
#   'accepted_pay_in_methods': [{'id': 1,
#     'code': 'CREDIT_CARD',
#     'requires_credit_card': True,
#     'event_tracking_code': 'cc',
#     'icon': 'credit-card',
#     'enabled': True,
#     'translated_name': 'Carte bancaire',
#     'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#    {'id': 10,
#     'code': 'MANGOPAY_PAYPAL',
#     'requires_credit_card': False,
#     'event_tracking_code': 'mangopay_paypal',
#     'icon': 'paypal',
#     'enabled': True,
#     'translated_name': 'PayPal',
#     'note': ''}],
#   'created_at': '13/02 12:17',
#   'color1': 'Blanc',
#   'color2': None,
#   'material': 'Bois, Bambou',
#   'status': 'Bon état',
#   'secure_purchase': True,
#   'performance': None,
#   'stats_visible': True,
#   'can_push_up': False,
#   'size_guide_faq_entry_id': None,
#   'localization': 'manual'}]

# %%
df_final = pd.json_normalize(data)
df_final
# Out:
#            id                                              title  brand_id  \
# 0   907487278                                       Sottopentola    280391
# 1   900688413                                             Libro          1
# 2   901057979              Candelabro Normann Copenaghen Heima 4   4109681
# 3   903185522  Le monde merveilleux des papillons tropicaux, ...         1
# 4   902746483                                    Noragami T. 1-2         1
# 5   901623118                                     Marco de fotos     14663
# 6   903356829                       Atrapasueños azul y amarillo     35735
# 7   895473220                                  👼🏻 Cute Angels 👼🏻   3425289
# 8   899693670  Très gros lot de livres et beaux livres pour f...         1
# 9   890246121                       Lot de livres humoristiques,         1
# 10  896230905                              Cute little Angels 👼🏻   3425289
# 11  902696223                        Life is short love is rare          1
# 12  903375057         5 Classeurs documentaires, sujets divers,          1
# 13  896279052                                    Livre Tatouages         1
# 14  907486168                            Magnifique Déco maison      14867
# 15  890847566                             tapiz pared decorativo         1
# 16  900896387                Star Wars El despertar de la fuerza         1
# 17  891653177  Campania Decor/ Set Vintage di 6 Bicchieri da ...     75138
# 18  898714869                Vides poches/ sous-verres Rose Gold     35735
# 19  898792847                       Bilancia Farmacista fine 800         1
# 20  897011611                  Verres cristal d'Arques lot de 12         1
# 21  893775500                      Gravidanza nascita e infanzia         1
# 22  901385747                                  Housse de couette    669490
# 23  901378546                                            Meuble     184302
#
#     size_id  status_id  disposal_conditions   user_id owner_id  country_id  \
# 0       NaN          1                    4  51227227     None          18
# 1       NaN          2                    4  52875067     None           7
# 2       NaN          2                    4  51903684     None          18
# 3       NaN          2                    4  31582421     None          16
# 4       NaN          2                    6  52352901     None          16
# 5       NaN          6                    4  52861181     None           7
# 6       NaN          6                    4  52252308     None           7
# 7       NaN          6                    4  26537858     None          10
# 8       NaN          3                    4  30613382     None          16
# 9       NaN          2                    4  27507928     None          16
# 10      NaN          6                    4  26537858     None          10
# 11      NaN          2                    4  29240179     None          16
# 12      NaN          2                    4  33463828     None          19
# 13      NaN          1                    4  25226828     None          16
# 14      NaN          2                    4  51026818     None          16
# 15      NaN          6                    4  42832695     None           7
# 16      NaN          2                    4  52754682     None           7
# 17      NaN          2                    4  48855501     None          18
# 18      NaN          6                    4  52745212     None          16
# 19      NaN          3                    4  50949518     None          18
# 20      NaN          1                    4  52719371     None          16
# 21      NaN          2                    4  52569328     None          18
# 22   1315.0          6                    4  52540480     None          16
# 23      NaN          3                    4  52420032     None          16
#
#     catalog_id  ...  user.photo.dominant_color_opaque  \
# 0         1961  ...                               NaN
# 1         2029  ...                               NaN
# 2         1957  ...                           #C1E6ED
# 3         2041  ...                           #C1E6ED
# 4         2018  ...                           #C1E6ED
# 5         1937  ...                           #C1E6ED
# 6         1929  ...                           #C1E6ED
# 7         1956  ...                           #C1E6ED
# 8         1980  ...                           #C1E6ED
# 9         2028  ...                           #C1E6ED
# 10        1956  ...                           #C1E6ED
# 11        2029  ...                           #C1E6ED
# 12        1980  ...                           #C1E6ED
# 13        2031  ...                               NaN
# 14        1941  ...                           #C1E6ED
# 15        1937  ...                           #C1E6ED
# 16        2018  ...                           #C1E6ED
# 17        2011  ...                           #C1E6ED
# 18        1962  ...                           #C1E6ED
# 19        1941  ...                           #C1E6ED
# 20        2011  ...                           #C1E6ED
# 21        2036  ...                               NaN
# 22        1943  ...                               NaN
# 23        1941  ...                               NaN
#
#                                 user.photo.thumbnails  \
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'type': 'thumb310', 'url': 'https://images.v...
# 3   [{'type': 'thumb310', 'url': 'https://images.v...
# 4   [{'type': 'thumb310', 'url': 'https://images.v...
# 5   [{'type': 'thumb310', 'url': 'https://images.v...
# 6   [{'type': 'thumb310', 'url': 'https://images.v...
# 7   [{'type': 'thumb310', 'url': 'https://images.v...
# 8   [{'type': 'thumb310', 'url': 'https://images.v...
# 9   [{'type': 'thumb310', 'url': 'https://images.v...
# 10  [{'type': 'thumb310', 'url': 'https://images.v...
# 11  [{'type': 'thumb310', 'url': 'https://images.v...
# 12  [{'type': 'thumb310', 'url': 'https://images.v...
# 13                                                NaN
# 14  [{'type': 'thumb310', 'url': 'https://images.v...
# 15  [{'type': 'thumb310', 'url': 'https://images.v...
# 16  [{'type': 'thumb310', 'url': 'https://images.v...
# 17  [{'type': 'thumb310', 'url': 'https://images.v...
# 18  [{'type': 'thumb310', 'url': 'https://images.v...
# 19  [{'type': 'thumb310', 'url': 'https://images.v...
# 20  [{'type': 'thumb310', 'url': 'https://images.v...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#     user.photo.is_suspicious  user.photo.orientation  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                      False                     NaN
# 3                      False                     NaN
# 4                      False                     NaN
# 5                      False                     NaN
# 6                      False                     NaN
# 7                      False                     NaN
# 8                      False                     NaN
# 9                      False                     NaN
# 10                     False                     NaN
# 11                     False                     NaN
# 12                     False                     NaN
# 13                       NaN                     NaN
# 14                     False                     NaN
# 15                     False                     NaN
# 16                     False                     NaN
# 17                     False                     NaN
# 18                     False                     NaN
# 19                     False                     NaN
# 20                     False                     NaN
# 21                       NaN                     NaN
# 22                       NaN                     NaN
# 23                       NaN                     NaN
#
#         user.photo.high_resolution.id user.photo.high_resolution.timestamp  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2   02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ                         1.612184e+09
# 3   02_00e47_T6NB4mYjMsgHWvdQqZfGZu2p                         1.609849e+09
# 4   02_00992_XUUfAaivWcr9VM92igPUbnbX                         1.612629e+09
# 5   02_02560_JG54F1k8UDPbgKK6azJLSGe7                         1.613174e+09
# 6   02_02660_QprZwKaVHijaAgJbLR7Czxbs                         1.612532e+09
# 7   02_016d6_wkTibGb4DcwwF7QKmLdHMju4                         1.609521e+09
# 8   02_01f37_c2C9bNhrDiKJ6ZJiXnbrNhTw                         1.605247e+09
# 9   02_01d18_MWrv5ZZmTcoqtsi7q1UR34nk                         1.605237e+09
# 10  02_016d6_wkTibGb4DcwwF7QKmLdHMju4                         1.609521e+09
# 11  02_01c82_7R1yC7pgwFF5UeV9M3APaLjD                         1.607781e+09
# 12  02_008ef_dW58cZ9vgzhqzUK5UZ6gd22Z                         1.604407e+09
# 13                                NaN                                  NaN
# 14  02_003d5_yy6d67E2iByDseWvcbsNCnUH                         1.613327e+09
# 15  01_00227_ev974ix8anmHBgs9NpL2n42m                         1.603976e+09
# 16  02_017b0_DXc5TxBpEafuk3BCrqKKBzoE                         1.613089e+09
# 17  02_003e6_6STttQ76cjkvHczHVzBtYccy                         1.609767e+09
# 18  02_0080e_peebsuphVPCaQoKYeznpYGfy                         1.612992e+09
# 19  02_019b1_x7E53jbX27u8a1XPjDX4GFjn                         1.611987e+09
# 20  02_00794_G2wDCsT92vJqCDzDZKi3EPEQ                         1.612974e+09
# 21                                NaN                                  NaN
# 22                                NaN                                  NaN
# 23                                NaN                                  NaN
#
#     user.photo.high_resolution.orientation  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
#
#                              user.photo.full_size_url  user.photo.extra  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2   https://images.vinted.net/thumbs/02_0255a_Zrkz...                []
# 3   https://images.vinted.net/thumbs/02_00e47_T6NB...                []
# 4   https://images.vinted.net/thumbs/02_00992_XUUf...                []
# 5   https://images.vinted.net/thumbs/02_02560_JG54...                []
# 6   https://images.vinted.net/thumbs/02_02660_QprZ...                []
# 7   https://images.vinted.net/thumbs/02_016d6_wkTi...                []
# 8   https://images.vinted.net/thumbs/02_01f37_c2C9...                []
# 9   https://images.vinted.net/thumbs/02_01d18_MWrv...                []
# 10  https://images.vinted.net/thumbs/02_016d6_wkTi...                []
# 11  https://images.vinted.net/thumbs/02_01c82_7R1y...                []
# 12  https://images.vinted.net/thumbs/02_008ef_dW58...                []
# 13                                                NaN               NaN
# 14  https://images.vinted.net/thumbs/02_003d5_yy6d...                []
# 15  https://images.vinted.net/thumbs/01_00227_ev97...                []
# 16  https://images.vinted.net/thumbs/02_017b0_DXc5...                []
# 17  https://images.vinted.net/thumbs/02_003e6_6STt...                []
# 18  https://images.vinted.net/thumbs/02_0080e_peeb...                []
# 19  https://images.vinted.net/thumbs/02_019b1_x7E5...                []
# 20  https://images.vinted.net/thumbs/02_00794_G2wD...                []
# 21                                                NaN               NaN
# 22                                                NaN               NaN
# 23                                                NaN               NaN
#
#     user.location_description
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
#
# [24 rows x 226 columns]

# %%
for i in [2, 3, 4, 5, 6]:
    URL = "https://www.vinted.fr/api/v2/items?catalog_ids=1918&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page="+str(i)+"&per_page=24&time=1613472454&search_session_id=d9bb6071-1852-4bb4-87e0-95848788cf02"
    #print(URL)
    headers.update({'referer': 'https://www.vinted.fr/vetements?catalog[]=1918&time=1613472454&page='+str(i)})
    #print(headers['referer'])
    response = requests.get(URL, headers=headers)
    data = response.json()["items"]
    df = pd.json_normalize(data)
    df_final = pd.concat([df_final, df])
df_final
# Out:
#            id                                              title  brand_id  \
# 0   907487278                                       Sottopentola    280391
# 1   900688413                                             Libro          1
# 2   901057979              Candelabro Normann Copenaghen Heima 4   4109681
# 3   903185522  Le monde merveilleux des papillons tropicaux, ...         1
# 4   902746483                                    Noragami T. 1-2         1
# ..        ...                                                ...       ...
# 19  905877943                                          Bougeoirs         1
# 20  907280415    Plat de service ou décoration en verre soufflé      80630
# 21  904156490     Next Year in Havana - Chanel Cleeton - anglais         1
# 22  904148683                             Agir & réussir - Aliso         1
# 23  904137540  The First Move, a negotiator's companion - Ala...         1
#
#    size_id  status_id  disposal_conditions   user_id owner_id  country_id  \
# 0      NaN          1                    4  51227227     None          18
# 1      NaN          2                    4  52875067     None           7
# 2      NaN          2                    4  51903684     None          18
# 3      NaN          2                    4  31582421     None          16
# 4      NaN          2                    6  52352901     None          16
# ..     ...        ...                  ...       ...      ...         ...
# 19     NaN          2                    4  52685530     None          16
# 20     NaN          6                    4  17818168     None          16
# 21     NaN          1                    4  45698670     None          16
# 22     NaN          1                    4  45698670     None          16
# 23     NaN          1                    4  45698670     None          16
#
#     catalog_id  ...  user.photo.dominant_color_opaque  \
# 0         1961  ...                               NaN
# 1         2029  ...                               NaN
# 2         1957  ...                           #C1E6ED
# 3         2041  ...                           #C1E6ED
# 4         2018  ...                           #C1E6ED
# ..         ...  ...                               ...
# 19        1957  ...                               NaN
# 20        1960  ...                           #C1E6ED
# 21        2029  ...                           #C1E6ED
# 22        2036  ...                           #C1E6ED
# 23        2041  ...                           #C1E6ED
#
#                                 user.photo.thumbnails  \
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'type': 'thumb310', 'url': 'https://images.v...
# 3   [{'type': 'thumb310', 'url': 'https://images.v...
# 4   [{'type': 'thumb310', 'url': 'https://images.v...
# ..                                                ...
# 19                                                NaN
# 20  [{'type': 'thumb310', 'url': 'https://images.v...
# 21  [{'type': 'thumb310', 'url': 'https://images.v...
# 22  [{'type': 'thumb310', 'url': 'https://images.v...
# 23  [{'type': 'thumb310', 'url': 'https://images.v...
#
#     user.photo.is_suspicious  user.photo.orientation  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                      False                     NaN
# 3                      False                     NaN
# 4                      False                     NaN
# ..                       ...                     ...
# 19                       NaN                     NaN
# 20                     False                     NaN
# 21                     False                     NaN
# 22                     False                     NaN
# 23                     False                     NaN
#
#         user.photo.high_resolution.id user.photo.high_resolution.timestamp  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2   02_0255a_ZrkzMa9SqGUn4JNVa1CNxUUJ                         1.612184e+09
# 3   02_00e47_T6NB4mYjMsgHWvdQqZfGZu2p                         1.609849e+09
# 4   02_00992_XUUfAaivWcr9VM92igPUbnbX                         1.612629e+09
# ..                                ...                                  ...
# 19                                NaN                                  NaN
# 20  02_01f47_np8FcZpZUKBzY5wJRst1EcaH                         1.612650e+09
# 21  02_01730_tbtKpdA34AsWhHLKtyEU8oAe                         1.606239e+09
# 22  02_01730_tbtKpdA34AsWhHLKtyEU8oAe                         1.606239e+09
# 23  02_01730_tbtKpdA34AsWhHLKtyEU8oAe                         1.606239e+09
#
#     user.photo.high_resolution.orientation  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
#
#                              user.photo.full_size_url  user.photo.extra  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2   https://images.vinted.net/thumbs/02_0255a_Zrkz...                []
# 3   https://images.vinted.net/thumbs/02_00e47_T6NB...                []
# 4   https://images.vinted.net/thumbs/02_00992_XUUf...                []
# ..                                                ...               ...
# 19                                                NaN               NaN
# 20  https://images.vinted.net/thumbs/02_01f47_np8F...                []
# 21  https://images.vinted.net/thumbs/02_01730_tbtK...                []
# 22  https://images.vinted.net/thumbs/02_01730_tbtK...                []
# 23  https://images.vinted.net/thumbs/02_01730_tbtK...                []
#
#     user.location_description
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
#
# [144 rows x 226 columns]

# %%
check = list(set(df_final.id))
check
# Out:
# [896279052,
#  895119890,
#  901385747,
#  904688147,
#  907328531,
#  899457555,
#  905313816,
#  886322715,
#  900688413,
#  884076574,
#  905330205,
#  907280415,
#  900627492,
#  899526188,
#  907487278,
#  894627894,
#  891653177,
#  894047803,
#  894417981,
#  895473220,
#  894913605,
#  899531334,
#  903135305,
#  889793615,
#  887856208,
#  901154383,
#  900063831,
#  894667354,
#  893343835,
#  901081692,
#  894293089,
#  894967394,
#  899693670,
#  896828007,
#  902736491,
#  905330285,
#  903185522,
#  896729717,
#  906970231,
#  889120377,
#  898669179,
#  901401728,
#  894493312,
#  900896387,
#  893775500,
#  899568272,
#  903184017,
#  892168345,
#  902050462,
#  894106794,
#  899820208,
#  885451449,
#  898143420,
#  903107774,
#  905345729,
#  885640389,
#  899470537,
#  904148683,
#  903375057,
#  886283474,
#  899704019,
#  886197981,
#  901214951,
#  889473772,
#  895969522,
#  901068019,
#  898714869,
#  907314936,
#  907327741,
#  899360514,
#  904535815,
#  899801869,
#  898029838,
#  887403280,
#  899359510,
#  889145113,
#  892585753,
#  902696223,
#  901188897,
#  896067874,
#  895573284,
#  889980203,
#  900056876,
#  899485997,
#  891026224,
#  899446578,
#  895432499,
#  883985719,
#  896118072,
#  904137540,
#  895561032,
#  904156490,
#  901623118,
#  890847566,
#  893248850,
#  902389591,
#  902942041,
#  883278693,
#  902984039,
#  902746483,
#  899518327,
#  899453816,
#  905091961,
#  899478402,
#  893731718,
#  903987086,
#  898792847,
#  896384915,
#  896110485,
#  897011611,
#  903356829,
#  886767005,
#  907266980,
#  897058725,
#  906848167,
#  894035882,
#  899459501,
#  892560305,
#  905877943,
#  901057979,
#  894766529,
#  905860547,
#  902707146,
#  886564810,
#  899714507,
#  890774991,
#  882128850,
#  905361365,
#  901530070,
#  907486168,
#  891022812,
#  893582815,
#  906236896,
#  907324897,
#  897959908,
#  898663912,
#  890246121,
#  901378546,
#  903145458,
#  896230905,
#  901652478]

# %%
len(check)
# Out:
# 141
