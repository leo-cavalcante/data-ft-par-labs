# %% [markdown]
# # Vehicles

# %%
import os
os.chdir(r"/Users/oleoaraujo/Downloads/vehicles")

# %%
import pandas as pd

# %%
pwd()
# Out:
# '/Users/oleoaraujo/Downloads/vehicles'

# %% [markdown]
# ## Import file

# %%
df=pd.read_csv('vehicles.csv')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.to_csv('df.csv', index=False)

# %%
df=pd.read_csv(r'vehicles_tab.txt', sep='\t')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df=pd.read_csv(r'vehicles_pipe.txt', sep='|')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.to_csv('pipefile.txt', sep=' ', index=False)

# %%
pd.read_csv('pipefile.txt', sep=' ')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
pd.read_excel('vehicles.xlsx').head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.to_excel('filename.xlsx', index=False)

# %%
pd.read_json('vehicles.json')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
df.to_json("blaaaah.json", orient="split")

# %%
# !pip install pymysql
# Out:
# ...
#      |████████████████████████████████| 43 kB 1.9 MB/s eta 0:00:011
# ...

# %%
# !pip install sqlalchemy
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 8.6 MB/s eta 0:00:01
# ...

# %%
# !pip install getpass3
# Out:
# ...
#   Created wheel for getpass3: filename=getpass3-1.2-py3-none-any.whl size=1774 sha256=f509c5a4a897853fdfc71890ea46c2e82207a037bcae264e0f6a2df029fefa9c
#   Stored in directory: /Users/oleoaraujo/Library/Caches/pip/wheels/10/ef/14/ff2622d718321c0984d27a9d5392a17f3f93214152e91f37db
# Successfully built getpass3
# ...

# %%
import pymysql
from sqlalchemy import create_engine
from getpass import getpass

# %%
#credentials
username='root'
server='localhost'
database='publications'
password=getpass()
# Out:
# ········

# %%
#engine=create_engine("https://www.website.com")
engine=create_engine(f"mysql+pymysql://{username}:{password}@{server}/{database}")

# %%
pd.read_sql_query("select * from authors", engine)
# Out:
#           au_id        au_lname     au_fname         phone  \
# 0   172-32-1176           White      Johnson  408 496-7223
# 1   213-46-8915           Green     Marjorie  415 986-7020
# 2   238-95-7766          Carson       Cheryl  415 548-7723
# 3   267-41-2394         O'Leary      Michael  408 286-2428
# 4   274-80-9391        Straight         Dean  415 834-2919
# 5   341-22-1782           Smith      Meander  913 843-0462
# 6   409-56-7008          Bennet      Abraham  415 658-9932
# 7   427-17-2319            Dull          Ann  415 836-7128
# 8   472-27-2349      Gringlesby         Burt  707 938-6445
# 9   486-29-1786        Locksley     Charlene  415 585-4620
# 10  527-72-3246          Greene  Morningstar  615 297-2723
# 11  648-92-1872  Blotchet-Halls     Reginald  503 745-6402
# 12  672-71-3249        Yokomoto        Akiko  415 935-4228
# 13  712-45-1867    del Castillo        Innes  615 996-8275
# 14  722-51-5454        DeFrance       Michel  219 547-9982
# ...

# %%
pd.read_sql_table('employee',engine)
# Out:
#        emp_id      fname minit      lname  job_id  job_lvl pub_id  hire_date
# 0   A-C71970F       Aria             Cruz      10       87   1389 1991-10-26
# 1   A-R89858F    Annette           Roulet       6      152   9999 1990-02-21
# 2   AMD15433F        Ann     M      Devon       3      200   9952 1991-07-16
# 3   ARD36773F    Anabela     R  Domingues       8      100   0877 1993-01-27
# 4   CFH28514M     Carlos     F   Hernadez       5      211   9999 1989-04-21
# 5   CGS88322F     Carine     G    Schmitt      13       64   1389 1992-07-07
# 6   DBT39435M     Daniel     B     Tonini      11       75   0877 1990-01-01
# 7   DWR65030M      Diego     W       Roel       6      192   1389 1991-12-16
# 8   ENL44273F  Elizabeth     N    Lincoln      14       35   0877 1990-07-24
# 9   F-C16315M  Francisco            Chang       4      227   9952 1990-11-03
# 10  GHT50241M       Gary     H     Thomas       9      170   0736 1988-08-09
# ...

# %%
from sqlalchemy import inspect
inspector=inspect(engine)
inspector.get_table_names()
# Out:
# ['authors',
#  'discounts',
#  'employee',
#  'jobs',
#  'most_profiting_authors',
#  'pub_info',
#  'publishers',
#  'roysched',
#  'sales',
#  'stores',
#  'titleauthor',
#  'titles']

# %%
df.to_sql('new_authors', engine, if_exists='replace', index=False)
