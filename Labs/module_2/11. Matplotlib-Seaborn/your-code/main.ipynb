# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, label='linear')
plt.plot(x, z, label='quadratic')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %%
plt.plot(x, y, x, z, x, 2*x**2)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2)

ax1.plot(x, y)
ax1.set_title('linear')

ax2.plot(x, z)
ax2.set_title('quadratic')
# Out:
# Text(0.5, 1.0, 'quadratic')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
# Method 2

fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(16,4))

ax1.plot(x, y)
ax1.set_title('linear')

ax2.plot(x, z)
ax2.set_title('quadratic')
# Out:
# Text(0.5, 1.0, 'quadratic')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y = x**2
z = np.exp(x)

fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(16,4))

ax1.plot(x, y, "r", x, z, "g")
ax1.set_title('Normal')

ax2.plot(x, y, "r", x, z, "g")
ax2.set_yscale("log")
ax2.set_title('Logarithmic')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
y = x**2
z = np.exp(x)

fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(16,4))

ax1.plot(x, y, label='x quadratic')
ax1.plot(x, z, "g", label='exponential x')
ax1.set_title('Normal')
ax1.legend()

ax2.plot(x, y, label='x quadratic')
ax2.plot(x, z, "g", label='exponential x')
ax2.set_yscale("log")
ax2.set_title('Logarithmic')
ax2.legend()

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
import os
print(os.getcwd())
os.chdir("../../../data")
print(os.getcwd())
# Out:
# /Users/oleoaraujo/Documents/GitHub/data-ft-par-labs/Labs/data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-220-01a77ccb1b1c> in <module>
#       1 import os
#       2 print(os.getcwd())
# ----> 3 os.chdir("../../../data")
#       4 print(os.getcwd())
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../data'

# %%
# your code here
fitbit = pd.read_csv("Fitbit2.csv")

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
list(fitbit.columns)
# Out:
# ['Date',
#  'Calorie burned',
#  'Steps',
#  'Distance',
#  'Floors',
#  'Minutes Sedentary',
#  'Minutes Lightly Active',
#  'Minutes Fairly Active',
#  'Minutes Very Active',
#  'Activity Calories',
#  'MinutesOfSleep',
#  'MinutesOfBeingAwake',
#  'NumberOfAwakings',
#  'LengthOfRestInMinutes',
#  'Distance_miles',
#  'Days',
#  'Days_encoded',
#  'Work_or_Weekend',
#  'Hours Sleep',
#  'Sleep efficiency',
#  'Yesterday_sleep',
#  'Yesterday_sleep_efficiency',
#  'Months',
#  'Months_encoded']

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
data=fitbit['Steps'].groupby(fitbit['Months_encoded']).median()

f, [month, day] = plt.subplots(1, 2, figsize=(12,4))

plt.sca(month)
data.plot(kind='bar')
#plt.xticks(rotation=45)
plt.xticks(range(12), ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], rotation=45)
plt.title("Median steps per Month")
plt.xlabel("Months")
plt.ylabel("Steps")

#plt.bar(x=data.index.astype(str), y=data.values, height=10)

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

data = fitbit["Steps"].groupby(fitbit.Work_or_Weekend).median()
plt.sca(day)
data.plot(kind="bar")
plt.title("Work day or weekend")
plt.ylabel("Steps")
plt.xlabel("Type of day")
plt.xticks(range(2),["Weekend","Work"], rotation=0)

#plt.savefig('../figures/steps_month_type-of-day.png', dpi = 300)
# Out:
# ([<matplotlib.axis.XTick at 0x11712d100>,
# ...
#  [Text(0, 0, 'Weekend'), Text(1, 0, 'Work')])

# %%
plt.savefig('../figures/steps_month_type-of-day.png', dpi = 300)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
print(os.getcwd())
titanic = pd.read_csv("/Users/oleoaraujo/Documents/GitHub/data-ft-par-labs/Labs/data/titanic.csv")
# Out:
# /Users/oleoaraujo/Documents/GitHub/data-ft-par-labs/Labs/module_2/11. Matplotlib-Seaborn/your-code

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
print(titanic.select_dtypes(include=np.number).dtypes)
titanic.select_dtypes(include=np.number)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# ...

# %%
# CATEGORICAL VARIABLES
# your code here
print(titanic.select_dtypes(include=object).dtypes)
titanic.select_dtypes(include=object)
# Out:
# Name        object
# Gender      object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use("seaborn-darkgrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic["Age"].hist(bins=20)

plt.title('Histogram of Age')
plt.xlabel("Age")
plt.ylabel("Number of people")
# Out:
# Text(0, 0.5, 'Number of people')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, ax = plt.subplots(1,3,figsize=(16,4))

bins=[10,20,50]

for i in range(3):
    #bin10.plot(kind="hist",bins=10)
    plt.sca(ax[i])
    titanic["Age"].hist(bins=bins[i])
    plt.title(f"Age Histogram with "+str(bins[i])+" bins")
    plt.xlabel("Age")
    plt.ylabel("Number of observations")

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bin size affects the granularity of data shown and therefore give me more details about smaller or larger
intervals of age. With a smaller interval of age, it is possible to see a lot of discrepancy

We can conclude that the Age Distribution, with a large number of bins, demonstrate that ir is not a perfectly
assymetrical distribution as it is with a small number of bins. 
"""
# Out:
# '\nThe bin size affects the granularity of data shown and therefore give me more details about smaller or larger\nintervals of age. With a smaller interval of age, it is possible to see a lot of discrepancy\n\nWe can conclude that the Age Distribution, with a large number of bins, demonstrate that ir is not a perfectly\nassymetrical distribution as it is with a small number of bins. \n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
import seaborn as sns
# your code here
sns.distplot(titanic.Age,bins=30, hist=True, kde=True, color="blue")
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
a = titanic.Gender.value_counts()
a.plot(kind='bar', color="gray")
plt.xticks(rotation=0, size=15)
plt.yticks(size=15)
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.countplot(titanic.Gender, color="yellow",order=["female","male"])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(titanic.Pclass)
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic.boxplot("Age", color = "green")
# Out:
# <AxesSubplot:>

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot(data=titanic.Age, color = "yellow")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The last plot adds up the density of the distribution of ages.
It is like the combination of a Age Distribution plot and a BoxPlot, containing the sum of information of both plots.
"""
# Out:
# '\nThe last plot adds up the density of the distribution of ages.\nIt is like the combination of a Age Distribution plot and a BoxPlot, containing the sum of information of both plots.\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic.Age, titanic.Fare)
plt.xlabel("Age",size=15)
plt.ylabel("Fare",size=15)
# Out:
# Text(0, 0.5, 'Fare')

# %%
# Method 2 - seaborn
# your code here
sns.regplot(x=titanic.Age,y=titanic.Fare)
plt.xlabel("Age",size=15)
plt.ylabel("Fare",size=15)
# Out:
# Text(0, 0.5, 'Fare')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr())
#sns.heatmap(df, annot=True, annot_kws={"size": 7})
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated features are Parch with SibSp.
"""
# Out:
# '\nThe most correlated features are Parch with SibSp.\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x=titanic.Pclass, y=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(data = titanic, col = 'Gender')
g.map(plt.hist, 'Age')
plt.show()

# %%
# your code here
g = sns.FacetGrid(titanic, col="Gender", row="Pclass")
g.map_dataframe(sns.histplot,"Age")
